# %% [markdown]
# # Test the API of EOD Historical Data

# %%
import requests
import json

# %% [markdown]
# # Create a helper function to pull data with the EOD API

# %%
def get_eod_data(symbol, api_token='OeAFFmMliFG5orCUuwAKQ8l4WWFQ67YX'):
    """
    This helper function pulls data from the EOD API.
    """
    
    # prep parameters for the API request
    base_url = 'https://eodhistoricaldata.com/api/fundamentals/'
    constructed_url = base_url + symbol
    params = {'api_token': api_token}

    # request data from the API, and returns an error messages if something goes wrong;
    # otherwise returns the entire json from the API
    r = requests.get(constructed_url, params=params)
    if r.status_code != 200:
        return "Error: the EOD API service failed."
    else:
        return r.json()

# test
payload = get_eod_data('AAPL.US', api_token='OeAFFmMliFG5orCUuwAKQ8l4WWFQ67YX')
print(json.dumps(payload, indent=4))
# Out:
# {
#     "General": {
#         "Code": "AAPL",
#         "Type": "Common Stock",
#         "Name": "Apple Inc",
#         "Exchange": "NASDAQ",
#         "CurrencyCode": "USD",
#         "CurrencyName": "US Dollar",
#         "CurrencySymbol": "$",
#         "CountryName": "USA",
#         "CountryISO": "US",
#         "ISIN": "US0378331005",
#         "CUSIP": "037833100",
#         "CIK": "320193",
#         "EmployerIdNumber": "94-2404110",
#         "FiscalYearEnd": "September",
#         "IPODate": "1980-12-12",
#         "InternationalDomestic": "International/Domestic",
#         "Sector": "Technology",
#         "Industry": "Consumer Electronics",
#         "GicSector": "Information Technology",
#         "GicGroup": "Technology Hardware & Equipment",
#         "GicIndustry": "Technology Hardware, Storage & Peripherals",
#         "GicSubIndustry": "Technology Hardware, Storage & Peripherals",
#         "HomeCategory": "Domestic",
#         "IsDelisted": false,
#         "Description": "Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. It also sells various related services. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, HomePod, iPod touch, and other Apple-branded and third-party accessories. It also provides AppleCare support services; cloud services store services; and operates various platforms, including the App Store, that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts. In addition, the company offers various services, such as Apple Arcade, a game subscription service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It sells and delivers third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was founded in 1977 and is headquartered in Cupertino, California.",
#         "Address": "One Apple Park Way, Cupertino, CA, United States, 95014",
#         "AddressData": {
#             "Street": "One Apple Park Way",
#             "City": "Cupertino",
#             "State": "CA",
#             "Country": "United States",
#             "ZIP": "95014"
#         },
#         "Listings": {
#             "0": {
#                 "Code": "0R2V",
#                 "Exchange": "LSE",
#                 "Name": "0R2V"
#             },
#             "1": {
#                 "Code": "AAPL",
#                 "Exchange": "BA",
#                 "Name": "Apple Inc. CEDEAR"
#             },
#             "2": {
#                 "Code": "AAPL34",
#                 "Exchange": "SA",
#                 "Name": "Apple Inc"
#             }
#         },
#         "Officers": {
#             "0": {
#                 "Name": "Mr. Timothy D. Cook",
#                 "Title": "CEO & Director",
#                 "YearBorn": "1961"
#             },
#             "1": {
#                 "Name": "Mr. Luca  Maestri",
#                 "Title": "CFO & Sr. VP",
#                 "YearBorn": "1964"
#             },
#             "2": {
#                 "Name": "Mr. Jeffrey E. Williams",
#                 "Title": "Chief Operating Officer",
#                 "YearBorn": "1964"
#             },
#             "3": {
#                 "Name": "Ms. Katherine L. Adams",
#                 "Title": "Sr. VP, Gen. Counsel & Sec.",
#                 "YearBorn": "1964"
#             },
#             "4": {
#                 "Name": "Ms. Deirdre  O'Brien",
#                 "Title": "Sr. VP of People & Retail",
#                 "YearBorn": "1967"
#             },
#             "5": {
#                 "Name": "Mr. Chris  Kondo",
#                 "Title": "Sr. Director of Corp. Accounting",
#                 "YearBorn": "NA"
#             },
#             "6": {
#                 "Name": "Mr. James  Wilson",
#                 "Title": "Chief Technology Officer",
#                 "YearBorn": "NA"
#             },
#             "7": {
#                 "Name": "Ms. Mary  Demby",
#                 "Title": "Chief Information Officer",
#                 "YearBorn": "NA"
#             },
#             "8": {
#                 "Name": "Ms. Nancy  Paxton",
#                 "Title": "Sr. Director of Investor Relations & Treasury",
#                 "YearBorn": "NA"
#             },
#             "9": {
#                 "Name": "Mr. Greg  Joswiak",
#                 "Title": "Sr. VP of Worldwide Marketing",
#                 "YearBorn": "NA"
#             }
#         },
#         "Phone": "408-996-1010",
#         "WebURL": "http://www.apple.com",
#         "LogoURL": "/img/logos/US/aapl.png",
#         "FullTimeEmployees": 147000,
#         "UpdatedAt": "2021-10-05"
#     },
#     "Highlights": {
#         "MarketCapitalization": 2343486357504,
#         "MarketCapitalizationMln": 2343486.3575,
#         "EBITDA": 110934999040,
#         "PERatio": 27.7545,
#         "PEGRatio": 2.0008,
#         "WallStreetTargetPrice": 167.92,
#         "BookValue": 3.882,
#         "DividendShare": 0.835,
#         "DividendYield": 0.006,
#         "EarningsShare": 5.108,
#         "EPSEstimateCurrentYear": 5.59,
#         "EPSEstimateNextYear": 5.68,
#         "EPSEstimateNextQuarter": 1.11,
#         "EPSEstimateCurrentQuarter": 1,
#         "MostRecentQuarter": "2021-06-30",
#         "ProfitMargin": 0.25,
#         "OperatingMarginTTM": 0.2879,
#         "ReturnOnAssetsTTM": 0.193,
#         "ReturnOnEquityTTM": 1.2713,
#         "RevenueTTM": 347155005440,
#         "RevenuePerShareTTM": 20.61,
#         "QuarterlyRevenueGrowthYOY": 0.364,
#         "GrossProfitTTM": 104956000000,
#         "DilutedEpsTTM": 5.108,
#         "QuarterlyEarningsGrowthYOY": 1
#     },
#     "Valuation": {
#         "TrailingPE": 27.7545,
#         "ForwardPE": 26.2467,
#         "PriceSalesTTM": 6.7508,
#         "PriceBookMRQ": 37.5606,
#         "EnterpriseValue": 2373802262528,
#         "EnterpriseValueRevenue": 7.1279,
#         "EnterpriseValueEbitda": 21.6181
#     },
#     "SharesStats": {
#         "SharesOutstanding": 16530199552,
#         "SharesFloat": 16513305231,
#         "PercentInsiders": 0.07100000000000001,
#         "PercentInstitutions": 58.672000000000004,
#         "SharesShort": 100926641,
#         "SharesShortPriorMonth": 96838699,
#         "ShortRatio": 1.28,
#         "ShortPercentOutstanding": 0.01,
#         "ShortPercentFloat": 0.0061
#     },
#     "Technicals": {
#         "Beta": 1.2222,
#         "52WeekHigh": 157.26,
#         "52WeekLow": 106.6342,
#         "50DayMA": 148.216,
#         "200DayMA": 137.3779,
#         "SharesShort": 100926641,
#         "SharesShortPriorMonth": 96838699,
#         "ShortRatio": 1.28,
#         "ShortPercent": 0.0061
#     },
#     "SplitsDividends": {
#         "ForwardAnnualDividendRate": 0.88,
#         "ForwardAnnualDividendYield": 0.0063,
#         "PayoutRatio": 0.1663,
#         "DividendDate": "2021-08-12",
#         "ExDividendDate": "2021-08-06",
#         "LastSplitFactor": "4:1",
#         "LastSplitDate": "2020-08-31",
#         "NumberDividendsByYear": {
#             "0": {
#                 "Year": 1989,
#                 "Count": 2
#             },
#             "1": {
#                 "Year": 1990,
#                 "Count": 4
#             },
#             "2": {
#                 "Year": 1991,
#                 "Count": 4
#             },
#             "3": {
#                 "Year": 1992,
#                 "Count": 4
#             },
#             "4": {
#                 "Year": 1993,
#                 "Count": 4
#             },
#             "5": {
#                 "Year": 1994,
#                 "Count": 4
#             },
#             "6": {
#                 "Year": 1995,
#                 "Count": 4
#             },
#             "7": {
#                 "Year": 2012,
#                 "Count": 2
#             },
#             "8": {
#                 "Year": 2013,
#                 "Count": 4
#             },
#             "9": {
#                 "Year": 2014,
#                 "Count": 4
#             },
#             "10": {
#                 "Year": 2015,
#                 "Count": 4
#             },
#             "11": {
#                 "Year": 2016,
#                 "Count": 4
#             },
#             "12": {
#                 "Year": 2017,
#                 "Count": 4
#             },
#             "13": {
#                 "Year": 2018,
#                 "Count": 4
#             },
#             "14": {
#                 "Year": 2019,
#                 "Count": 4
#             },
#             "15": {
#                 "Year": 2020,
#                 "Count": 4
#             },
#             "16": {
#                 "Year": 2021,
#                 "Count": 3
#             }
#         }
#     },
#     "AnalystRatings": {
#         "Rating": 4.15,
#         "TargetPrice": 149.33,
#         "StrongBuy": 21,
#         "Buy": 8,
#         "Hold": 8,
#         "Sell": 2,
#         "StrongSell": 1
#     },
#     "Holders": {
#         "Institutions": {
#             "0": {
#                 "name": "Vanguard Group Inc",
#                 "date": "2021-06-30",
#                 "totalShares": 7.6523,
#                 "totalAssets": 4.3113,
#                 "currentShares": 1264936543,
#                 "change": 25553808,
#                 "change_p": 2.0618
#             },
#             "1": {
#                 "name": "BlackRock Inc",
#                 "date": "2021-06-30",
#                 "totalShares": 6.2232,
#                 "totalAssets": 3.9216,
#                 "currentShares": 1028698316,
#                 "change": -26307286,
#                 "change_p": -2.4936
#             },
#             "2": {
#                 "name": "Berkshire Hathaway Inc",
#                 "date": "2021-06-30",
#                 "totalShares": 5.3668,
#                 "totalAssets": 41.465,
#                 "currentShares": 887135554,
#                 "change": 0,
#                 "change_p": 0
#             },
#             "3": {
#                 "name": "State Street Corporation",
#                 "date": "2021-06-30",
#                 "totalShares": 3.7663,
#                 "totalAssets": 4.4943,
#                 "currentShares": 622579947,
#                 "change": -414294,
#                 "change_p": -0.0665
#             },
#             "4": {
#                 "name": "FMR Inc",
#                 "date": "2021-06-30",
#                 "totalShares": 2.1201,
#                 "totalAssets": 3.7605,
#                 "currentShares": 350462986,
#                 "change": 5510838,
#                 "change_p": 1.5976
#             },
#             "5": {
#                 "name": "Geode Capital Management, LLC",
#                 "date": "2021-06-30",
#                 "totalShares": 1.5376,
#                 "totalAssets": 4.7817,
#                 "currentShares": 254162496,
#                 "change": 6185412,
#                 "change_p": 2.4943
#             },
#             "6": {
#                 "name": "Northern Trust Corp",
#                 "date": "2021-06-30",
#                 "totalShares": 1.1691,
#                 "totalAssets": 4.6623,
#                 "currentShares": 193253001,
#                 "change": -5613994,
#                 "change_p": -2.823
#             },
#             "7": {
#                 "name": "T. Rowe Price Associates, Inc.",
#                 "date": "2021-06-30",
#                 "totalShares": 1.1657,
#                 "totalAssets": 2.4463,
#                 "currentShares": 192697039,
#                 "change": -7855329,
#                 "change_p": -3.9168
#             },
#             "8": {
#                 "name": "Bank of New York Mellon Corp",
#                 "date": "2021-06-30",
#                 "totalShares": 0.9312,
#                 "totalAssets": 4.0781,
#                 "currentShares": 153929495,
#                 "change": -764237,
#                 "change_p": -0.494
#             },
#             "9": {
#                 "name": "JPMorgan Chase & Co",
#                 "date": "2021-06-30",
#                 "totalShares": 0.8506,
#                 "totalAssets": 2.2974,
#                 "currentShares": 140600896,
#                 "change": 13179622,
#                 "change_p": 10.3433
#             },
#             "10": {
#                 "name": "Morgan Stanley - Brokerage Accounts",
#                 "date": "2021-06-30",
#                 "totalShares": 0.7614,
#                 "totalAssets": 2.2737,
#                 "currentShares": 125859709,
#                 "change": 3472624,
#                 "change_p": 2.8374
#             },
#             "11": {
#                 "name": "Legal & General Group PLC",
#                 "date": "2021-06-30",
#                 "totalShares": 0.6259,
#                 "totalAssets": 4.7381,
#                 "currentShares": 103466388,
#                 "change": 3613141,
#                 "change_p": 3.6185
#             },
#             "12": {
#                 "name": "Nuveen Asset Management, LLC",
#                 "date": "2021-06-30",
#                 "totalShares": 0.5753,
#                 "totalAssets": 3.8824,
#                 "currentShares": 95102989,
#                 "change": -12790805,
#                 "change_p": -11.855
#             },
#             "13": {
#                 "name": "Bank of America Corp",
#                 "date": "2021-06-30",
#                 "totalShares": 0.5428,
#                 "totalAssets": 1.3183,
#                 "currentShares": 89729184,
#                 "change": -60247887,
#                 "change_p": -40.1714
#             },
#             "14": {
#                 "name": "Wells Fargo & Co",
#                 "date": "2021-06-30",
#                 "totalShares": 0.4855,
#                 "totalAssets": 2.4087,
#                 "currentShares": 80247163,
#                 "change": -2717272,
#                 "change_p": -3.2752
#             },
#             "15": {
#                 "name": "Charles Schwab Investment Management Inc",
#                 "date": "2021-06-30",
#                 "totalShares": 0.4649,
#                 "totalAssets": 3.4974,
#                 "currentShares": 76847971,
#                 "change": 898803,
#                 "change_p": 1.1834
#             },
#             "16": {
#                 "name": "Goldman Sachs Group Inc",
#                 "date": "2021-06-30",
#                 "totalShares": 0.4217,
#                 "totalAssets": 2.1388,
#                 "currentShares": 69709737,
#                 "change": 1384172,
#                 "change_p": 2.0258
#             },
#             "17": {
#                 "name": "Mellon Investments Corporation",
#                 "date": "2021-06-30",
#                 "totalShares": 0.4158,
#                 "totalAssets": 4.4232,
#                 "currentShares": 68734645,
#                 "change": -1523314,
#                 "change_p": -2.1682
#             },
#             "18": {
#                 "name": "UBS Asset Mgmt Americas Inc",
#                 "date": "2021-06-30",
#                 "totalShares": 0.4142,
#                 "totalAssets": 4.0122,
#                 "currentShares": 68465124,
#                 "change": -1868959,
#                 "change_p": -2.6573
#             },
#             "19": {
#                 "name": "Swiss National Bank",
#                 "date": "2021-06-30",
#                 "totalShares": 0.4141,
#                 "totalAssets": 5.7826,
#                 "currentShares": 68455408,
#                 "change": 2852012,
#                 "change_p": 4.3474
#             }
#         },
#         "Funds": {
#             "0": {
#                 "name": "Vanguard Total Stock Mkt Idx Inv",
#                 "date": "2021-08-31",
#                 "totalShares": 2.7096,
#                 "totalAssets": 5.2023,
#                 "currentShares": 447908839,
#                 "change": -558418,
#                 "change_p": -0.1245
#             },
#             "1": {
#                 "name": "Vanguard 500 Index Investor",
#                 "date": "2021-08-31",
#                 "totalShares": 1.9856,
#                 "totalAssets": 6.2207,
#                 "currentShares": 328219523,
#                 "change": 1517581,
#                 "change_p": 0.4645
#             },
#             "2": {
#                 "name": "SPDR\u00ae S&P 500 ETF Trust",
#                 "date": "2021-09-30",
#                 "totalShares": 1.0045,
#                 "totalAssets": 6.0643,
#                 "currentShares": 166047529,
#                 "change": -608586,
#                 "change_p": -0.3652
#             },
#             "3": {
#                 "name": "Fidelity\u00ae 500 Index",
#                 "date": "2021-07-31",
#                 "totalShares": 0.8992,
#                 "totalAssets": 6.1359,
#                 "currentShares": 148633391,
#                 "change": 742094,
#                 "change_p": 0.5018
#             },
#             "4": {
#                 "name": "Invesco QQQ Trust",
#                 "date": "2021-09-30",
#                 "totalShares": 0.8592,
#                 "totalAssets": 10.9925,
#                 "currentShares": 142024095,
#                 "change": 389946,
#                 "change_p": 0.2753
#             },
#             "5": {
#                 "name": "Vanguard Growth Index Investor",
#                 "date": "2021-08-31",
#                 "totalShares": 0.7478,
#                 "totalAssets": 10.5214,
#                 "currentShares": 123618988,
#                 "change": 445577,
#                 "change_p": 0.3617
#             },
#             "6": {
#                 "name": "iShares Core S&P 500 ETF",
#                 "date": "2021-09-30",
#                 "totalShares": 0.7438,
#                 "totalAssets": 6.0678,
#                 "currentShares": 122946583,
#                 "change": -92390,
#                 "change_p": -0.0751
#             },
#             "7": {
#                 "name": "Vanguard Institutional Index I",
#                 "date": "2021-08-31",
#                 "totalShares": 0.7351,
#                 "totalAssets": 6.2144,
#                 "currentShares": 121520282,
#                 "change": -1047600,
#                 "change_p": -0.8547
#             },
#             "8": {
#                 "name": "Vanguard Information Technology ETF",
#                 "date": "2021-08-31",
#                 "totalShares": 0.4664,
#                 "totalAssets": 20.0588,
#                 "currentShares": 77100626,
#                 "change": -469264,
#                 "change_p": -0.605
#             },
#             "9": {
#                 "name": "State St S&P 500\u00ae Indx SL Cl III",
#                 "date": "2021-08-31",
#                 "totalShares": 0.4167,
#                 "totalAssets": 6.1485,
#                 "currentShares": 68880557,
#                 "change": 206400,
#                 "change_p": 0.3005
#             },
#             "10": {
#                 "name": "Technology Select Sector SPDR\u00ae ETF",
#                 "date": "2021-09-30",
#                 "totalShares": 0.4027,
#                 "totalAssets": 21.9242,
#                 "currentShares": 66565625,
#                 "change": 34842,
#                 "change_p": 0.0524
#             },
#             "11": {
#                 "name": "iShares Russell 1000 Growth ETF",
#                 "date": "2021-09-30",
#                 "totalShares": 0.3175,
#                 "totalAssets": 10.3973,
#                 "currentShares": 52480757,
#                 "change": 10073,
#                 "change_p": 0.0192
#             },
#             "12": {
#                 "name": "Blackrock Eq Idx Fund CF",
#                 "date": "2021-06-30",
#                 "totalShares": 0.2782,
#                 "totalAssets": 5.8842,
#                 "currentShares": 45980576,
#                 "change": 22094,
#                 "change_p": 0.0481
#             },
#             "13": {
#                 "name": "Russell 1000 Index Fund",
#                 "date": "2021-08-31",
#                 "totalShares": 0.261,
#                 "totalAssets": 5.507,
#                 "currentShares": 43150983,
#                 "change": 115636,
#                 "change_p": 0.2687
#             },
#             "14": {
#                 "name": "NT S&P 500 Index Fund - NL",
#                 "date": "2021-06-30",
#                 "totalShares": 0.2309,
#                 "totalAssets": 5.8876,
#                 "currentShares": 38166718,
#                 "change": -741968,
#                 "change_p": -1.9069
#             },
#             "15": {
#                 "name": "Fidelity\u00ae Blue Chip Growth",
#                 "date": "2021-07-31",
#                 "totalShares": 0.2062,
#                 "totalAssets": 8.7298,
#                 "currentShares": 34077675,
#                 "change": 0,
#                 "change_p": 0
#             },
#             "16": {
#                 "name": "Fidelity Growth Compy Commingled Pl 3",
#                 "date": "2021-07-31",
#                 "totalShares": 0.2038,
#                 "totalAssets": 6.9547,
#                 "currentShares": 33683220,
#                 "change": 0,
#                 "change_p": 0
#             },
#             "17": {
#                 "name": "Fidelity\u00ae Growth Company",
#                 "date": "2021-07-31",
#                 "totalShares": 0.2022,
#                 "totalAssets": 7.4201,
#                 "currentShares": 33420848,
#                 "change": 0,
#                 "change_p": 0
#             },
#             "18": {
#                 "name": "T. Rowe Price Blue Chip Growth",
#                 "date": "2021-06-30",
#                 "totalShares": 0.2017,
#                 "totalAssets": 4.4424,
#                 "currentShares": 33339448,
#                 "change": -4346836,
#                 "change_p": -11.5343
#             },
#             "19": {
#                 "name": "T. Rowe Price US Large-Cap Core Grwth Eq",
#                 "date": "2021-06-30",
#                 "totalShares": 0.2017,
#                 "totalAssets": 4.4424,
#                 "currentShares": 33339448,
#                 "change": -4346836,
#                 "change_p": -11.5343
#             }
#         }
#     },
#     "InsiderTransactions": {
#         "0": {
#             "date": "2021-08-25",
#             "ownerCik": null,
#             "ownerName": "Timothy D Cook",
#             "transactionDate": "2021-08-25",
#             "transactionCode": "S",
#             "transactionAmount": 2386440,
#             "transactionPrice": 148.58,
#             "transactionAcquiredDisposed": "D",
#             "postTransactionAmount": null,
#             "secLink": "http://www.sec.gov/Archives/edgar/data/320193/000032019321000073/xslF345X03/wf-form4_163001701613155.xml"
#         },
#         "1": {
#             "date": "2021-08-06",
#             "ownerCik": null,
#             "ownerName": "Deirdre O'brien",
#             "transactionDate": "2021-08-06",
#             "transactionCode": "S",
#             "transactionAmount": 14877,
#             "transactionPrice": 145.99,
#             "transactionAcquiredDisposed": "D",
#             "postTransactionAmount": null,
#             "secLink": "http://www.sec.gov/Archives/edgar/data/320193/000032019321000069/xslF345X03/wf-form4_162854822510730.xml"
#         },
#         "2": {
#             "date": "2021-08-02",
#             "ownerCik": null,
#             "ownerName": "Katherine L. Adams",
#             "transactionDate": "2021-08-02",
#             "transactionCode": "S",
#             "transactionAmount": 17000,
#             "transactionPrice": 145.89,
#             "transactionAcquiredDisposed": "D",
#             "postTransactionAmount": 324164,
#             "secLink": "http://www.sec.gov/Archives/edgar/data/320193/000032019321000067/xslF345X03/wf-form4_162811622543495.xml"
#         },
#         "3": {
#             "date": "2021-05-03",
#             "ownerCik": null,
#             "ownerName": "Katherine L Adams",
#             "transactionDate": "2021-05-03",
#             "transactionCode": "S",
#             "transactionAmount": 17000,
#             "transactionPrice": 132.8,
#             "transactionAcquiredDisposed": "D",
#             "postTransactionAmount": 333044,
#             "secLink": "http://www.sec.gov/Archives/edgar/data/320193/000032019321000059/xslF345X03/wf-form4_162025381465785.xml"
#         },
#         "4": {
#             "date": "2021-05-03",
#             "ownerCik": null,
#             "ownerName": "Luca Maestri",
#             "transactionDate": "2021-05-03",
#             "transactionCode": "S",
#             "transactionAmount": 121072,
#             "transactionPrice": 132.81,
#             "transactionAcquiredDisposed": "D",
#             "postTransactionAmount": 143961,
#             "secLink": "http://www.sec.gov/Archives/edgar/data/320193/000032019321000060/xslF345X03/wf-form4_162025388592461.xml"
#         },
#         "5": {
#             "date": "2021-04-16",
#             "ownerCik": null,
#             "ownerName": "Deirdre O'brien",
#             "transactionDate": "2021-04-16",
#             "transactionCode": "S",
#             "transactionAmount": 18216,
#             "transactionPrice": 134.01,
#             "transactionAcquiredDisposed": "D",
#             "postTransactionAmount": null,
#             "secLink": "http://www.sec.gov/Archives/edgar/data/320193/000032019321000050/xslF345X03/wf-form4_161887148361718.xml"
#         },
#         "6": {
#             "date": "2021-04-05",
#             "ownerCik": null,
#             "ownerName": "Jeffrey E Williams",
#             "transactionDate": "2021-04-05",
#             "transactionCode": "S",
#             "transactionAmount": 133867,
#             "transactionPrice": 125.74,
#             "transactionAcquiredDisposed": "D",
#             "postTransactionAmount": null,
#             "secLink": "http://www.sec.gov/Archives/edgar/data/320193/000032019321000046/xslF345X03/wf-form4_161766207883637.xml"
#         },
#         "7": {
#             "date": "2020-11-03",
#             "ownerCik": null,
#             "ownerName": "Katherine L Adams",
#             "transactionDate": "2020-11-03",
#             "transactionCode": "S",
#             "transactionAmount": 17000,
#             "transactionPrice": 110.42,
#             "transactionAcquiredDisposed": "D",
#             "postTransactionAmount": 320784,
#             "secLink": "http://www.sec.gov/Archives/edgar/data/320193/000032019320000099/xslF345X03/wf-form4_160461904119340.xml"
#         },
#         "8": {
#             "date": "2020-10-16",
#             "ownerCik": null,
#             "ownerName": "Chris Kondo",
#             "transactionDate": "2020-10-16",
#             "transactionCode": "S",
#             "transactionAmount": 14840,
#             "transactionPrice": 121.34,
#             "transactionAcquiredDisposed": "D",
#             "postTransactionAmount": null,
#             "secLink": "http://www.sec.gov/Archives/edgar/data/320193/000032019320000089/xslF345X03/wf-form4_160314661733333.xml"
#         },
#         "9": {
#             "date": "2020-10-16",
#             "ownerCik": null,
#             "ownerName": "Deirdre O'brien",
#             "transactionDate": "2020-10-16",
#             "transactionCode": "S",
#             "transactionAmount": 31200,
#             "transactionPrice": 119.8,
#             "transactionAcquiredDisposed": "D",
#             "postTransactionAmount": null,
#             "secLink": "http://www.sec.gov/Archives/edgar/data/320193/000032019320000090/xslF345X03/wf-form4_160314673986899.xml"
#         },
#         "10": {
#             "date": "2020-10-09",
#             "ownerCik": null,
#             "ownerName": "Luca Maestri",
#             "transactionDate": "2020-10-09",
#             "transactionCode": "S",
#             "transactionAmount": 243431,
#             "transactionPrice": 116.89,
#             "transactionAcquiredDisposed": "D",
#             "postTransactionAmount": 110272,
#             "secLink": "http://www.sec.gov/Archives/edgar/data/320193/000032019320000086/xslF345X03/wf-form4_160262821333467.xml"
#         },
#         "11": {
#             "date": "2020-10-02",
#             "ownerCik": null,
#             "ownerName": "Jeffrey E Williams",
#             "transactionDate": "2020-10-02",
#             "transactionCode": "S",
#             "transactionAmount": 257343,
#             "transactionPrice": 113.59,
#             "transactionAcquiredDisposed": "D",
#             "postTransactionAmount": null,
#             "secLink": "http://www.sec.gov/Archives/edgar/data/320193/000032019320000084/xslF345X03/wf-form4_160193720275669.xml"
#         },
#         "12": {
#             "date": "2020-08-25",
#             "ownerCik": null,
#             "ownerName": "Timothy D Cook",
#             "transactionDate": "2020-08-25",
#             "transactionCode": "S",
#             "transactionAmount": 265160,
#             "transactionPrice": 496.91,
#             "transactionAcquiredDisposed": "D",
#             "postTransactionAmount": null,
#             "secLink": "http://www.sec.gov/Archives/edgar/data/320193/000032019320000066/xslF345X03/wf-form4_159839550969947.xml"
#         },
#         "13": {
#             "date": "2020-05-08",
#             "ownerCik": null,
#             "ownerName": "Chris Kondo",
#             "transactionDate": "2020-05-08",
#             "transactionCode": "S",
#             "transactionAmount": 4491,
#             "transactionPrice": 305.62,
#             "transactionAcquiredDisposed": "D",
#             "postTransactionAmount": 7370,
#             "secLink": "http://www.sec.gov/Archives/edgar/data/320193/000032019320000056/xslF345X03/wf-form4_158932261319105.xml"
#         },
#         "14": {
#             "date": "2020-04-16",
#             "ownerCik": null,
#             "ownerName": "Deirdre O'brien",
#             "transactionDate": "2020-04-16",
#             "transactionCode": "S",
#             "transactionAmount": 9137,
#             "transactionPrice": 285.12,
#             "transactionAcquiredDisposed": "D",
#             "postTransactionAmount": null,
#             "secLink": "http://www.sec.gov/Archives/edgar/data/320193/000032019320000045/xslF345X03/wf-form4_158716268511263.xml"
#         },
#         "15": {
#             "date": "2020-04-07",
#             "ownerCik": null,
#             "ownerName": "Luca Maestri",
#             "transactionDate": "2020-04-07",
#             "transactionCode": "S",
#             "transactionAmount": 41062,
#             "transactionPrice": 264.44,
#             "transactionAcquiredDisposed": "D",
#             "postTransactionAmount": 65427,
#             "secLink": "http://www.sec.gov/Archives/edgar/data/320193/000032019320000041/xslF345X03/wf-form4_158647142758084.xml"
#         },
#         "16": {
#             "date": "2020-04-02",
#             "ownerCik": null,
#             "ownerName": "Jeffrey E. Williams",
#             "transactionDate": "2020-04-02",
#             "transactionCode": "S",
#             "transactionAmount": 41062,
#             "transactionPrice": 241.44,
#             "transactionAcquiredDisposed": "D",
#             "postTransactionAmount": null,
#             "secLink": "http://www.sec.gov/Archives/edgar/data/320193/000032019320000039/xslF345X03/wf-form4_158595308536827.xml"
#         },
#         "17": {
#             "date": "2020-02-03",
#             "ownerCik": null,
#             "ownerName": "Arthur D Levinson",
#             "transactionDate": "2020-02-03",
#             "transactionCode": "S",
#             "transactionAmount": 1429,
#             "transactionPrice": 304.11,
#             "transactionAcquiredDisposed": "D",
#             "postTransactionAmount": 1134712,
#             "secLink": "http://www.sec.gov/Archives/edgar/data/320193/000032019320000021/xslF345X03/wf-form4_158085927075591.xml"
#         },
#         "18": {
#             "date": "2019-11-05",
#             "ownerCik": null,
#             "ownerName": "Arthur D Levinson",
#             "transactionDate": "2019-11-05",
#             "transactionCode": "S",
#             "transactionAmount": 37394,
#             "transactionPrice": 257.79,
#             "transactionAcquiredDisposed": "D",
#             "postTransactionAmount": 1170677,
#             "secLink": "http://www.sec.gov/Archives/edgar/data/320193/000032019319000121/xslF345X03/wf-form4_157316940649990.xml"
#         },
#         "19": {
#             "date": "2019-10-16",
#             "ownerCik": null,
#             "ownerName": "Chris Kondo",
#             "transactionDate": "2019-10-16",
#             "transactionCode": "S",
#             "transactionAmount": 3932,
#             "transactionPrice": 233.26,
#             "transactionAcquiredDisposed": "D",
#             "postTransactionAmount": 15464,
#             "secLink": "http://www.sec.gov/Archives/edgar/data/320193/000032019319000112/xslF345X03/wf-form4_157135144806488.xml"
#         }
#     },
#     "ESGScores": {
#         "Disclaimer": "The ESG data currently in a very early Beta stage and not intended for any production use. It will be removed from the feed on December 31, 2020.",
#         "RatingDate": "2019-01-01",
#         "TotalEsg": 26.15,
#         "TotalEsgPercentile": 36.8,
#         "EnvironmentScore": 0.99,
#         "EnvironmentScorePercentile": 5,
#         "SocialScore": 13.98,
#         "SocialScorePercentile": 5,
#         "GovernanceScore": 11.18,
#         "GovernanceScorePercentile": 5,
#         "ControversyLevel": 3,
#         "ActivitiesInvolvement": {
#             "0": {
#                 "Activity": "adult",
#                 "Involvement": "No"
#             },
#             "1": {
#                 "Activity": "alcoholic",
#                 "Involvement": "No"
#             },
#             "2": {
#                 "Activity": "animalTesting",
#                 "Involvement": "No"
#             },
#             "3": {
#                 "Activity": "catholic",
#                 "Involvement": "No"
#             },
#             "4": {
#                 "Activity": "controversialWeapons",
#                 "Involvement": "No"
#             },
#             "5": {
#                 "Activity": "smallArms",
#                 "Involvement": "No"
#             },
#             "6": {
#                 "Activity": "furLeather",
#                 "Involvement": "No"
#             },
#             "7": {
#                 "Activity": "gambling",
#                 "Involvement": "No"
#             },
#             "8": {
#                 "Activity": "gmo",
#                 "Involvement": "No"
#             },
#             "9": {
#                 "Activity": "militaryContract",
#                 "Involvement": "No"
#             },
#             "10": {
#                 "Activity": "nuclear",
#                 "Involvement": "No"
#             },
#             "11": {
#                 "Activity": "pesticides",
#                 "Involvement": "No"
#             },
#             "12": {
#                 "Activity": "palmOil",
#                 "Involvement": "No"
#             },
#             "13": {
#                 "Activity": "coal",
#                 "Involvement": "No"
#             },
#             "14": {
#                 "Activity": "tobacco",
#                 "Involvement": "No"
#             }
#         }
#     },
#     "outstandingShares": {
#         "annual": {
#             "0": {
#                 "date": "2021",
#                 "dateFormatted": "2021-12-31",
#                 "sharesMln": "16781.7350",
#                 "shares": 16781735000
#             },
#             "1": {
#                 "date": "2020",
#                 "dateFormatted": "2020-12-31",
#                 "sharesMln": "17113.6880",
#                 "shares": 17113687999.999998
#             },
#             "2": {
#                 "date": "2019",
#                 "dateFormatted": "2019-12-31",
#                 "sharesMln": "17818.4160",
#                 "shares": 17818416000
#             },
#             "3": {
#                 "date": "2018",
#                 "dateFormatted": "2018-12-31",
#                 "sharesMln": "19093.0080",
#                 "shares": 19093008000
#             },
#             "4": {
#                 "date": "2017",
#                 "dateFormatted": "2017-12-31",
#                 "sharesMln": "20631.1480",
#                 "shares": 20631148000
#             },
#             "5": {
#                 "date": "2016",
#                 "dateFormatted": "2016-12-31",
#                 "sharesMln": "21311.9800",
#                 "shares": 21311980000
#             },
#             "6": {
#                 "date": "2015",
#                 "dateFormatted": "2015-12-31",
#                 "sharesMln": "22376.5080",
#                 "shares": 22376508000
#             },
#             "7": {
#                 "date": "2014",
#                 "dateFormatted": "2014-12-31",
#                 "sharesMln": "23527.2120",
#                 "shares": 23527212000
#             },
#             "8": {
#                 "date": "2013",
#                 "dateFormatted": "2013-12-31",
#                 "sharesMln": "25240.6560",
#                 "shares": 25240656000
#             },
#             "9": {
#                 "date": "2012",
#                 "dateFormatted": "2012-12-31",
#                 "sharesMln": "26522.0760",
#                 "shares": 26522076000
#             },
#             "10": {
#                 "date": "2011",
#                 "dateFormatted": "2011-12-31",
#                 "sharesMln": "26364.0160",
#                 "shares": 26364016000
#             },
#             "11": {
#                 "date": "2010",
#                 "dateFormatted": "2010-12-31",
#                 "sharesMln": "26128.3120",
#                 "shares": 26128312000
#             },
#             "12": {
#                 "date": "2009",
#                 "dateFormatted": "2009-12-31",
#                 "sharesMln": "25753.9240",
#                 "shares": 25753924000
#             },
#             "13": {
#                 "date": "2008",
#                 "dateFormatted": "2008-12-31",
#                 "sharesMln": "25241.8320",
#                 "shares": 25241832000
#             },
#             "14": {
#                 "date": "2007",
#                 "dateFormatted": "2007-12-31",
#                 "sharesMln": "25201.5120",
#                 "shares": 25201512000
#             },
#             "15": {
#                 "date": "2006",
#                 "dateFormatted": "2006-12-31",
#                 "sharesMln": "24732.3160",
#                 "shares": 24732316000
#             },
#             "16": {
#                 "date": "2005",
#                 "dateFormatted": "2005-12-31",
#                 "sharesMln": "24477.7960",
#                 "shares": 24477796000
#             },
#             "17": {
#                 "date": "2004",
#                 "dateFormatted": "2004-12-31",
#                 "sharesMln": "23468.8720",
#                 "shares": 23468872000
#             },
#             "18": {
#                 "date": "2003",
#                 "dateFormatted": "2003-12-31",
#                 "sharesMln": "20849.2480",
#                 "shares": 20849248000
#             },
#             "19": {
#                 "date": "2002",
#                 "dateFormatted": "2002-12-31",
#                 "sharesMln": "20107.1920",
#                 "shares": 20107192000
#             },
#             "20": {
#                 "date": "2001",
#                 "dateFormatted": "2001-12-31",
#                 "sharesMln": "20020.5040",
#                 "shares": 20020504000
#             },
#             "21": {
#                 "date": "2000",
#                 "dateFormatted": "2000-12-31",
#                 "sharesMln": "18881.5200",
#                 "shares": 18881520000
#             },
#             "22": {
#                 "date": "1999",
#                 "dateFormatted": "1999-12-31",
#                 "sharesMln": "19982.7040",
#                 "shares": 19982704000
#             },
#             "23": {
#                 "date": "1998",
#                 "dateFormatted": "1998-12-31",
#                 "sharesMln": "19270.9440",
#                 "shares": 19270944000
#             },
#             "24": {
#                 "date": "1997",
#                 "dateFormatted": "1997-12-31",
#                 "sharesMln": "15661.9680",
#                 "shares": 15661968000
#             },
#             "25": {
#                 "date": "1996",
#                 "dateFormatted": "1996-12-31",
#                 "sharesMln": "13947.5840",
#                 "shares": 13947584000
#             },
#             "26": {
#                 "date": "1995",
#                 "dateFormatted": "1995-12-31",
#                 "sharesMln": "13775.3280",
#                 "shares": 13775328000
#             },
#             "27": {
#                 "date": "1994",
#                 "dateFormatted": "1994-12-31",
#                 "sharesMln": "13625.4720",
#                 "shares": 13625472000
#             },
#             "28": {
#                 "date": "1993",
#                 "dateFormatted": "1993-12-31",
#                 "sharesMln": "13099.0720",
#                 "shares": 13099072000
#             },
#             "29": {
#                 "date": "1992",
#                 "dateFormatted": "1992-12-31",
#                 "sharesMln": "13481.7910",
#                 "shares": 13481791000
#             },
#             "30": {
#                 "date": "1991",
#                 "dateFormatted": "1991-12-31",
#                 "sharesMln": "13670.5882",
#                 "shares": 13670588200
#             },
#             "31": {
#                 "date": "1990",
#                 "dateFormatted": "1990-12-31",
#                 "sharesMln": "13168.7500",
#                 "shares": 13168750000
#             },
#             "32": {
#                 "date": "1989",
#                 "dateFormatted": "1989-12-31",
#                 "sharesMln": "14560.0000",
#                 "shares": 14560000000
#             },
#             "33": {
#                 "date": "1988",
#                 "dateFormatted": "1988-12-31",
#                 "sharesMln": "14285.2640",
#                 "shares": 14285264000
#             },
#             "34": {
#                 "date": "1987",
#                 "dateFormatted": "1987-12-31",
#                 "sharesMln": "14063.2800",
#                 "shares": 14063280000
#             },
#             "35": {
#                 "date": "1986",
#                 "dateFormatted": "1986-12-31",
#                 "sharesMln": "14260.0640",
#                 "shares": 14260064000
#             },
#             "36": {
#                 "date": "1985",
#                 "dateFormatted": "1985-12-31",
#                 "sharesMln": "13837.8240",
#                 "shares": 13837824000
#             }
#         },
#         "quarterly": {
#             "0": {
#                 "date": "2021-Q2",
#                 "dateFormatted": "2021-06-30",
#                 "sharesMln": "16781.7350",
#                 "shares": 16781735000
#             },
#             "1": {
#                 "date": "2021-Q1",
#                 "dateFormatted": "2021-03-31",
#                 "sharesMln": "16929.1570",
#                 "shares": 16929157000
#             },
#             "2": {
#                 "date": "2020-Q4",
#                 "dateFormatted": "2020-12-31",
#                 "sharesMln": "17113.6880",
#                 "shares": 17113687999.999998
#             },
#             "3": {
#                 "date": "2020-Q3",
#                 "dateFormatted": "2020-09-30",
#                 "sharesMln": "17256.5210",
#                 "shares": 17256521000
#             },
#             "4": {
#                 "date": "2020-Q2",
#                 "dateFormatted": "2020-06-30",
#                 "sharesMln": "17419.1520",
#                 "shares": 17419152000
#             },
#             "5": {
#                 "date": "2020-Q1",
#                 "dateFormatted": "2020-03-31",
#                 "sharesMln": "17618.7640",
#                 "shares": 17618764000
#             },
#             "6": {
#                 "date": "2019-Q4",
#                 "dateFormatted": "2019-12-31",
#                 "sharesMln": "17818.4160",
#                 "shares": 17818416000
#             },
#             "7": {
#                 "date": "2019-Q3",
#                 "dateFormatted": "2019-09-30",
#                 "sharesMln": "18081.4920",
#                 "shares": 18081492000
#             },
#             "8": {
#                 "date": "2019-Q2",
#                 "dateFormatted": "2019-06-30",
#                 "sharesMln": "18405.5200",
#                 "shares": 18405520000
#             },
#             "9": {
#                 "date": "2019-Q1",
#                 "dateFormatted": "2019-03-31",
#                 "sharesMln": "18802.5840",
#                 "shares": 18802584000
#             },
#             "10": {
#                 "date": "2018-Q4",
#                 "dateFormatted": "2018-12-31",
#                 "sharesMln": "19093.0080",
#                 "shares": 19093008000
#             },
#             "11": {
#                 "date": "2018-Q3",
#                 "dateFormatted": "2018-09-30",
#                 "sharesMln": "19390.1880",
#                 "shares": 19390188000
#             },
#             "12": {
#                 "date": "2018-Q2",
#                 "dateFormatted": "2018-06-30",
#                 "sharesMln": "19706.4360",
#                 "shares": 19706436000
#             },
#             "13": {
#                 "date": "2018-Q1",
#                 "dateFormatted": "2018-03-31",
#                 "sharesMln": "20273.9720",
#                 "shares": 20273972000
#             },
#             "14": {
#                 "date": "2017-Q4",
#                 "dateFormatted": "2017-12-31",
#                 "sharesMln": "20631.1480",
#                 "shares": 20631148000
#             },
#             "15": {
#                 "date": "2017-Q3",
#                 "dateFormatted": "2017-09-30",
#                 "sharesMln": "20734.3400",
#                 "shares": 20734340000
#             },
#             "16": {
#                 "date": "2017-Q2",
#                 "dateFormatted": "2017-06-30",
#                 "sharesMln": "20933.9960",
#                 "shares": 20933996000
#             },
#             "17": {
#                 "date": "2017-Q1",
#                 "dateFormatted": "2017-03-31",
#                 "sharesMln": "21046.7520",
#                 "shares": 21046752000
#             },
#             "18": {
#                 "date": "2016-Q4",
#                 "dateFormatted": "2016-12-31",
#                 "sharesMln": "21311.9800",
#                 "shares": 21311980000
#             },
#             "19": {
#                 "date": "2016-Q3",
#                 "dateFormatted": "2016-09-30",
#                 "sharesMln": "21573.3320",
#                 "shares": 21573332000
#             },
#             "20": {
#                 "date": "2016-Q2",
#                 "dateFormatted": "2016-06-30",
#                 "sharesMln": "21891.1240",
#                 "shares": 21891124000
#             },
#             "21": {
#                 "date": "2016-Q1",
#                 "dateFormatted": "2016-03-31",
#                 "sharesMln": "22163.5440",
#                 "shares": 22163544000
#             },
#             "22": {
#                 "date": "2015-Q4",
#                 "dateFormatted": "2015-12-31",
#                 "sharesMln": "22376.5080",
#                 "shares": 22376508000
#             },
#             "23": {
#                 "date": "2015-Q3",
#                 "dateFormatted": "2015-09-30",
#                 "sharesMln": "22730.0760",
#                 "shares": 22730076000
#             },
#             "24": {
#                 "date": "2015-Q2",
#                 "dateFormatted": "2015-06-30",
#                 "sharesMln": "23092.3960",
#                 "shares": 23092396000
#             },
#             "25": {
#                 "date": "2015-Q1",
#                 "dateFormatted": "2015-03-31",
#                 "sharesMln": "23339.4320",
#                 "shares": 23339432000
#             },
#             "26": {
#                 "date": "2014-Q4",
#                 "dateFormatted": "2014-12-31",
#                 "sharesMln": "23527.2120",
#                 "shares": 23527212000
#             },
#             "27": {
#                 "date": "2014-Q3",
#                 "dateFormatted": "2014-09-30",
#                 "sharesMln": "23888.3280",
#                 "shares": 23888328000
#             },
#             "28": {
#                 "date": "2014-Q2",
#                 "dateFormatted": "2014-06-30",
#                 "sharesMln": "24206.8440",
#                 "shares": 24206844000
#             },
#             "29": {
#                 "date": "2014-Q1",
#                 "dateFormatted": "2014-03-31",
#                 "sharesMln": "24626.7840",
#                 "shares": 24626784000
#             },
#             "30": {
#                 "date": "2013-Q4",
# ...
#                     "grossProfit": "2894300000.00",
#                     "reconciledDepreciation": null,
#                     "ebit": "139700000.00",
#                     "ebitda": "305800000.00",
#                     "depreciationAndAmortization": "166100000.00",
#                     "nonOperatingIncomeNetOther": null,
#                     "operatingIncome": "110400000.00",
#                     "otherOperatingExpenses": "7866600000.00",
#                     "interestExpense": null,
#                     "taxProvision": null,
#                     "interestIncome": null,
#                     "netInterestIncome": null,
#                     "extraordinaryItems": null,
#                     "nonRecurring": null,
#                     "otherItems": null,
#                     "incomeTaxExpense": "53100000.00",
#                     "totalRevenue": "7977000000.00",
#                     "totalOperatingExpenses": "2783900000.00",
#                     "costOfRevenue": "5082700000.00",
#                     "totalOtherIncomeExpenseNet": "-29300000.00",
#                     "discontinuedOperations": null,
#                     "netIncomeFromContinuingOps": null,
#                     "netIncomeApplicableToCommonShares": null,
#                     "preferredStockAndOtherAdjustments": null
#                 },
#                 "1992-09-30": {
#                     "date": "1992-09-30",
#                     "filing_date": "1992-09-30",
#                     "currency_symbol": null,
#                     "researchDevelopment": null,
#                     "effectOfAccountingCharges": null,
#                     "incomeBeforeTax": "855500000.00",
#                     "minorityInterest": null,
#                     "netIncome": "530400000.00",
#                     "sellingGeneralAdministrative": "2289400000.00",
#                     "sellingAndMarketingExpenses": null,
#                     "grossProfit": "3312300000.00",
#                     "reconciledDepreciation": null,
#                     "ebit": "855500000.00",
#                     "ebitda": "1072700000.00",
#                     "depreciationAndAmortization": "217200000.00",
#                     "nonOperatingIncomeNetOther": null,
#                     "operatingIncome": "805700000.00",
#                     "otherOperatingExpenses": "6280800000.00",
#                     "interestExpense": null,
#                     "taxProvision": null,
#                     "interestIncome": null,
#                     "netInterestIncome": null,
#                     "extraordinaryItems": null,
#                     "nonRecurring": null,
#                     "otherItems": null,
#                     "incomeTaxExpense": "325100000.00",
#                     "totalRevenue": "7086500000.00",
#                     "totalOperatingExpenses": "2506600000.00",
#                     "costOfRevenue": "3774200000.00",
#                     "totalOtherIncomeExpenseNet": "-49800000.00",
#                     "discontinuedOperations": null,
#                     "netIncomeFromContinuingOps": null,
#                     "netIncomeApplicableToCommonShares": null,
#                     "preferredStockAndOtherAdjustments": null
#                 },
#                 "1991-09-30": {
#                     "date": "1991-09-30",
#                     "filing_date": "1991-09-30",
#                     "currency_symbol": null,
#                     "researchDevelopment": null,
#                     "effectOfAccountingCharges": null,
#                     "incomeBeforeTax": "499700000.00",
#                     "minorityInterest": null,
#                     "netIncome": "309800000.00",
#                     "sellingGeneralAdministrative": "2547400000.00",
#                     "sellingAndMarketingExpenses": null,
#                     "grossProfit": "3199100000.00",
#                     "reconciledDepreciation": null,
#                     "ebit": "499700000.00",
#                     "ebitda": "704100000.00",
#                     "depreciationAndAmortization": "204400000.00",
#                     "nonOperatingIncomeNetOther": null,
#                     "operatingIncome": "447300000.00",
#                     "otherOperatingExpenses": "5861500000.00",
#                     "interestExpense": null,
#                     "taxProvision": null,
#                     "interestIncome": null,
#                     "netInterestIncome": null,
#                     "extraordinaryItems": null,
#                     "nonRecurring": null,
#                     "otherItems": null,
#                     "incomeTaxExpense": "189900000.00",
#                     "totalRevenue": "6308800000.00",
#                     "totalOperatingExpenses": "2751800000.00",
#                     "costOfRevenue": "3109700000.00",
#                     "totalOtherIncomeExpenseNet": "-52400000.00",
#                     "discontinuedOperations": null,
#                     "netIncomeFromContinuingOps": null,
#                     "netIncomeApplicableToCommonShares": null,
#                     "preferredStockAndOtherAdjustments": null
#                 },
#                 "1990-09-30": {
#                     "date": "1990-09-30",
#                     "filing_date": "1990-09-30",
#                     "currency_symbol": null,
#                     "researchDevelopment": null,
#                     "effectOfAccountingCharges": null,
#                     "incomeBeforeTax": "778500000.00",
#                     "minorityInterest": null,
#                     "netIncome": "474900000.00",
#                     "sellingGeneralAdministrative": "2240200000.00",
#                     "sellingAndMarketingExpenses": null,
#                     "grossProfit": "3154900000.00",
#                     "reconciledDepreciation": null,
#                     "ebit": "778500000.00",
#                     "ebitda": "981200000.00",
#                     "depreciationAndAmortization": "202700000.00",
#                     "nonOperatingIncomeNetOther": null,
#                     "operatingIncome": "712000000.00",
#                     "otherOperatingExpenses": "4846400000.00",
#                     "interestExpense": null,
#                     "taxProvision": null,
#                     "interestIncome": null,
#                     "netInterestIncome": null,
#                     "extraordinaryItems": null,
#                     "nonRecurring": null,
#                     "otherItems": null,
#                     "incomeTaxExpense": "303600000.00",
#                     "totalRevenue": "5558400000.00",
#                     "totalOperatingExpenses": "2442900000.00",
#                     "costOfRevenue": "2403500000.00",
#                     "totalOtherIncomeExpenseNet": "-66500000.00",
#                     "discontinuedOperations": null,
#                     "netIncomeFromContinuingOps": null,
#                     "netIncomeApplicableToCommonShares": null,
#                     "preferredStockAndOtherAdjustments": null
#                 },
#                 "1989-09-30": {
#                     "date": "1989-09-30",
#                     "filing_date": "1989-09-30",
#                     "currency_symbol": null,
#                     "researchDevelopment": null,
#                     "effectOfAccountingCharges": null,
#                     "incomeBeforeTax": "744300000.00",
#                     "minorityInterest": null,
#                     "netIncome": "454000000.00",
#                     "sellingGeneralAdministrative": "1954900000.00",
#                     "sellingAndMarketingExpenses": null,
#                     "grossProfit": "2714000000.00",
#                     "reconciledDepreciation": null,
#                     "ebit": "744300000.00",
#                     "ebitda": "869100000.00",
#                     "depreciationAndAmortization": "124800000.00",
#                     "nonOperatingIncomeNetOther": null,
#                     "operatingIncome": "634300000.00",
#                     "otherOperatingExpenses": "4649700000.00",
#                     "interestExpense": null,
#                     "taxProvision": null,
#                     "interestIncome": null,
#                     "netInterestIncome": null,
#                     "extraordinaryItems": null,
#                     "nonRecurring": null,
#                     "otherItems": null,
#                     "incomeTaxExpense": "290300000.00",
#                     "totalRevenue": "5284000000.00",
#                     "totalOperatingExpenses": "2079700000.00",
#                     "costOfRevenue": "2570000000.00",
#                     "totalOtherIncomeExpenseNet": "-110000000.00",
#                     "discontinuedOperations": null,
#                     "netIncomeFromContinuingOps": null,
#                     "netIncomeApplicableToCommonShares": null,
#                     "preferredStockAndOtherAdjustments": null
#                 },
#                 "1988-09-30": {
#                     "date": "1988-09-30",
#                     "filing_date": "1988-09-30",
#                     "currency_symbol": null,
#                     "researchDevelopment": null,
#                     "effectOfAccountingCharges": null,
#                     "incomeBeforeTax": "656200000.00",
#                     "minorityInterest": null,
#                     "netIncome": "400300000.00",
#                     "sellingGeneralAdministrative": "1460200000.00",
#                     "sellingAndMarketingExpenses": null,
#                     "grossProfit": "2158200000.00",
#                     "reconciledDepreciation": null,
#                     "ebit": "656200000.00",
#                     "ebitda": "733900000.00",
#                     "depreciationAndAmortization": "77700000.00",
#                     "nonOperatingIncomeNetOther": null,
#                     "operatingIncome": "620300000.00",
#                     "otherOperatingExpenses": "3451100000.00",
#                     "interestExpense": null,
#                     "taxProvision": null,
#                     "interestIncome": null,
#                     "netInterestIncome": null,
#                     "extraordinaryItems": null,
#                     "nonRecurring": null,
#                     "otherItems": null,
#                     "incomeTaxExpense": "255900000.00",
#                     "totalRevenue": "4071400000.00",
#                     "totalOperatingExpenses": "1537900000.00",
#                     "costOfRevenue": "1913200000.00",
#                     "totalOtherIncomeExpenseNet": "-35900000.00",
#                     "discontinuedOperations": null,
#                     "netIncomeFromContinuingOps": null,
#                     "netIncomeApplicableToCommonShares": null,
#                     "preferredStockAndOtherAdjustments": null
#                 },
#                 "1987-09-30": {
#                     "date": "1987-09-30",
#                     "filing_date": "1987-09-30",
#                     "currency_symbol": null,
#                     "researchDevelopment": null,
#                     "effectOfAccountingCharges": null,
#                     "incomeBeforeTax": "410400000.00",
#                     "minorityInterest": null,
#                     "netIncome": "217500000.00",
#                     "sellingGeneralAdministrative": "993400000.00",
#                     "sellingAndMarketingExpenses": null,
#                     "grossProfit": "1435400000.00",
#                     "reconciledDepreciation": null,
#                     "ebit": "410400000.00",
#                     "ebitda": "480900000.00",
#                     "depreciationAndAmortization": "70500000.00",
#                     "nonOperatingIncomeNetOther": null,
#                     "operatingIncome": "371500000.00",
#                     "otherOperatingExpenses": "2289600000.00",
#                     "interestExpense": null,
#                     "taxProvision": null,
#                     "interestIncome": null,
#                     "netInterestIncome": null,
#                     "extraordinaryItems": null,
#                     "nonRecurring": null,
#                     "otherItems": null,
#                     "incomeTaxExpense": "192900000.00",
#                     "totalRevenue": "2661100000.00",
#                     "totalOperatingExpenses": "1063900000.00",
#                     "costOfRevenue": "1225700000.00",
#                     "totalOtherIncomeExpenseNet": "-38900000.00",
#                     "discontinuedOperations": null,
#                     "netIncomeFromContinuingOps": null,
#                     "netIncomeApplicableToCommonShares": null,
#                     "preferredStockAndOtherAdjustments": null
#                 },
#                 "1986-09-30": {
#                     "date": "1986-09-30",
#                     "filing_date": "1986-09-30",
#                     "currency_symbol": null,
#                     "researchDevelopment": null,
#                     "effectOfAccountingCharges": null,
#                     "incomeBeforeTax": "309800000.00",
#                     "minorityInterest": null,
#                     "netIncome": "154000000.00",
#                     "sellingGeneralAdministrative": "737300000.00",
#                     "sellingAndMarketingExpenses": null,
#                     "grossProfit": "1061900000.00",
#                     "reconciledDepreciation": null,
#                     "ebit": "309800000.00",
#                     "ebitda": "360900000.00",
#                     "depreciationAndAmortization": "51100000.00",
#                     "nonOperatingIncomeNetOther": null,
#                     "operatingIncome": "273500000.00",
#                     "otherOperatingExpenses": "1628400000.00",
#                     "interestExpense": null,
#                     "taxProvision": null,
#                     "interestIncome": null,
#                     "netInterestIncome": null,
#                     "extraordinaryItems": null,
#                     "nonRecurring": null,
#                     "otherItems": null,
#                     "incomeTaxExpense": "155800000.00",
#                     "totalRevenue": "1901900000.00",
#                     "totalOperatingExpenses": "788400000.00",
#                     "costOfRevenue": "840000000.00",
#                     "totalOtherIncomeExpenseNet": "-36300000.00",
#                     "discontinuedOperations": null,
#                     "netIncomeFromContinuingOps": null,
#                     "netIncomeApplicableToCommonShares": null,
#                     "preferredStockAndOtherAdjustments": null
#                 },
#                 "1985-09-30": {
#                     "date": "1985-09-30",
#                     "filing_date": "1985-09-30",
#                     "currency_symbol": null,
#                     "researchDevelopment": null,
#                     "effectOfAccountingCharges": null,
#                     "incomeBeforeTax": "120000000.00",
#                     "minorityInterest": null,
#                     "netIncome": "61200000.00",
#                     "sellingGeneralAdministrative": "653200000.00",
#                     "sellingAndMarketingExpenses": null,
#                     "grossProfit": "842300000.00",
#                     "reconciledDepreciation": null,
#                     "ebit": "120000000.00",
#                     "ebitda": "161800000.00",
#                     "depreciationAndAmortization": "41800000.00",
#                     "nonOperatingIncomeNetOther": null,
#                     "operatingIncome": "147300000.00",
#                     "otherOperatingExpenses": "1771000000.00",
#                     "interestExpense": null,
#                     "taxProvision": null,
#                     "interestIncome": null,
#                     "netInterestIncome": null,
#                     "extraordinaryItems": null,
#                     "nonRecurring": null,
#                     "otherItems": null,
#                     "incomeTaxExpense": "58800000.00",
#                     "totalRevenue": "1918300000.00",
#                     "totalOperatingExpenses": "695000000.00",
#                     "costOfRevenue": "1076000000.00",
#                     "totalOtherIncomeExpenseNet": "27300000.00",
#                     "discontinuedOperations": null,
#                     "netIncomeFromContinuingOps": null,
#                     "netIncomeApplicableToCommonShares": null,
#                     "preferredStockAndOtherAdjustments": null
#                 }
#             }
#         }
#     }
# }

# %% [markdown]
# # Understand what's in the payload returned by the EOD API

# %%
# get the list of top level keys in the payload
payload.keys()
# Out:
# dict_keys(['General', 'Highlights', 'Valuation', 'SharesStats', 'Technicals', 'SplitsDividends', 'AnalystRatings', 'Holders', 'InsiderTransactions', 'ESGScores', 'outstandingShares', 'Earnings', 'Financials'])

# %% [markdown]
# ### <font color=blue>Check what's in the "Earnings" payload</font>

# %%
payload['Earnings'].keys()
# Out:
# dict_keys(['History', 'Trend', 'Annual'])

# %%
payload['Earnings']['History']
# Out:
# {'2022-06-30': {'reportDate': '2022-07-25',
#   'date': '2022-06-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': None,
#   'epsEstimate': None,
#   'epsDifference': None,
#   'surprisePercent': None},
#  '2022-03-31': {'reportDate': '2022-04-26',
#   'date': '2022-03-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': None,
#   'epsEstimate': None,
#   'epsDifference': None,
#   'surprisePercent': None},
#  '2021-12-31': {'reportDate': '2022-01-25',
#   'date': '2021-12-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': None,
#   'epsEstimate': None,
#   'epsDifference': None,
#   'surprisePercent': None},
#  '2021-09-30': {'reportDate': '2021-10-27',
#   'date': '2021-09-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': None,
#   'epsEstimate': 1.23,
#   'epsDifference': None,
#   'surprisePercent': None},
#  '2021-06-30': {'reportDate': '2021-07-27',
#   'date': '2021-06-30',
#   'beforeAfterMarket': 'AfterMarket',
#   'currency': 'USD',
#   'epsActual': 1.3,
#   'epsEstimate': 1.0143,
#   'epsDifference': 0.2857,
#   'surprisePercent': 28.1672},
#  '2021-03-31': {'reportDate': '2021-04-28',
#   'date': '2021-03-31',
#   'beforeAfterMarket': 'AfterMarket',
#   'currency': 'USD',
#   'epsActual': 1.4,
#   'epsEstimate': 0.9888,
#   'epsDifference': 0.4112,
#   'surprisePercent': 41.5858},
#  '2020-12-31': {'reportDate': '2021-01-27',
#   'date': '2020-12-31',
#   'beforeAfterMarket': 'AfterMarket',
#   'currency': 'USD',
#   'epsActual': 1.68,
#   'epsEstimate': 1.4158,
#   'epsDifference': 0.2642,
#   'surprisePercent': 18.6608},
#  '2020-09-30': {'reportDate': '2020-10-29',
#   'date': '2020-09-30',
#   'beforeAfterMarket': 'AfterMarket',
#   'currency': 'USD',
#   'epsActual': 0.73,
#   'epsEstimate': 0.6987,
#   'epsDifference': 0.0313,
#   'surprisePercent': 4.4797},
#  '2020-06-30': {'reportDate': '2020-07-30',
#   'date': '2020-06-30',
#   'beforeAfterMarket': 'AfterMarket',
#   'currency': 'USD',
#   'epsActual': 0.65,
#   'epsEstimate': 0.51,
#   'epsDifference': 0.14,
#   'surprisePercent': 27.451},
#  '2020-03-31': {'reportDate': '2020-04-30',
#   'date': '2020-03-31',
#   'beforeAfterMarket': 'AfterMarket',
#   'currency': 'USD',
#   'epsActual': 0.64,
#   'epsEstimate': 0.56,
#   'epsDifference': 0.08,
#   'surprisePercent': 14.2857},
#  '2019-12-31': {'reportDate': '2020-01-28',
#   'date': '2019-12-31',
#   'beforeAfterMarket': 'AfterMarket',
#   'currency': 'USD',
#   'epsActual': 1.25,
#   'epsEstimate': 1.14,
#   'epsDifference': 0.11,
#   'surprisePercent': 9.6491},
#  '2019-09-30': {'reportDate': '2019-10-30',
#   'date': '2019-09-30',
#   'beforeAfterMarket': 'AfterMarket',
#   'currency': 'USD',
#   'epsActual': 0.76,
#   'epsEstimate': 0.71,
#   'epsDifference': 0.05,
#   'surprisePercent': 7.0423},
#  '2019-06-30': {'reportDate': '2019-07-30',
#   'date': '2019-06-30',
#   'beforeAfterMarket': 'AfterMarket',
#   'currency': 'USD',
#   'epsActual': 0.55,
#   'epsEstimate': 0.53,
#   'epsDifference': 0.02,
#   'surprisePercent': 3.7736},
#  '2019-03-31': {'reportDate': '2019-04-30',
#   'date': '2019-03-31',
#   'beforeAfterMarket': 'AfterMarket',
#   'currency': 'USD',
#   'epsActual': 0.62,
#   'epsEstimate': 0.59,
#   'epsDifference': 0.03,
#   'surprisePercent': 5.0847},
#  '2018-12-31': {'reportDate': '2019-01-29',
#   'date': '2018-12-31',
#   'beforeAfterMarket': 'AfterMarket',
#   'currency': 'USD',
#   'epsActual': 1.05,
#   'epsEstimate': 1.04,
#   'epsDifference': 0.01,
#   'surprisePercent': 0.9615},
#  '2018-09-30': {'reportDate': '2018-11-01',
#   'date': '2018-09-30',
#   'beforeAfterMarket': 'AfterMarket',
#   'currency': 'USD',
#   'epsActual': 0.73,
#   'epsEstimate': 0.7,
#   'epsDifference': 0.03,
#   'surprisePercent': 4.2857},
#  '2018-06-30': {'reportDate': '2018-07-31',
#   'date': '2018-06-30',
#   'beforeAfterMarket': 'AfterMarket',
#   'currency': 'USD',
#   'epsActual': 0.585,
#   'epsEstimate': 0.545,
#   'epsDifference': 0.04,
#   'surprisePercent': 7.3394},
#  '2018-03-31': {'reportDate': '2018-05-01',
#   'date': '2018-03-31',
#   'beforeAfterMarket': 'AfterMarket',
#   'currency': 'USD',
#   'epsActual': 0.6825,
#   'epsEstimate': 0.6725,
#   'epsDifference': 0.01,
#   'surprisePercent': 1.487},
#  '2017-12-31': {'reportDate': '2018-02-01',
#   'date': '2017-12-31',
#   'beforeAfterMarket': 'AfterMarket',
#   'currency': 'USD',
#   'epsActual': 0.9725,
#   'epsEstimate': 0.965,
#   'epsDifference': 0.0075,
#   'surprisePercent': 0.7772},
#  '2017-09-30': {'reportDate': '2017-11-02',
#   'date': '2017-09-30',
#   'beforeAfterMarket': 'AfterMarket',
#   'currency': 'USD',
#   'epsActual': 0.5175,
#   'epsEstimate': 0.4675,
#   'epsDifference': 0.05,
#   'surprisePercent': 10.6952},
#  '2017-06-30': {'reportDate': '2017-08-01',
#   'date': '2017-06-30',
#   'beforeAfterMarket': 'AfterMarket',
#   'currency': 'USD',
#   'epsActual': 0.4175,
#   'epsEstimate': 0.3925,
#   'epsDifference': 0.025,
#   'surprisePercent': 6.3694},
#  '2017-03-31': {'reportDate': '2017-05-02',
#   'date': '2017-03-31',
#   'beforeAfterMarket': 'AfterMarket',
#   'currency': 'USD',
#   'epsActual': 0.525,
#   'epsEstimate': 0.505,
#   'epsDifference': 0.02,
#   'surprisePercent': 3.9604},
#  '2016-12-31': {'reportDate': '2017-01-31',
#   'date': '2016-12-31',
#   'beforeAfterMarket': 'AfterMarket',
#   'currency': 'USD',
#   'epsActual': 0.84,
#   'epsEstimate': 0.8025,
#   'epsDifference': 0.0375,
#   'surprisePercent': 4.6729},
#  '2016-09-30': {'reportDate': '2016-10-25',
#   'date': '2016-09-30',
#   'beforeAfterMarket': 'AfterMarket',
#   'currency': 'USD',
#   'epsActual': 0.4175,
#   'epsEstimate': 0.415,
#   'epsDifference': 0.0025,
#   'surprisePercent': 0.6024},
#  '2016-06-30': {'reportDate': '2016-07-26',
#   'date': '2016-06-30',
#   'beforeAfterMarket': 'AfterMarket',
#   'currency': 'USD',
#   'epsActual': 0.355,
#   'epsEstimate': 0.345,
#   'epsDifference': 0.01,
#   'surprisePercent': 2.8986},
#  '2016-03-31': {'reportDate': '2016-04-26',
#   'date': '2016-03-31',
#   'beforeAfterMarket': 'AfterMarket',
#   'currency': 'USD',
#   'epsActual': 0.475,
#   'epsEstimate': 0.5,
#   'epsDifference': -0.025,
#   'surprisePercent': -5},
#  '2015-12-31': {'reportDate': '2016-01-26',
#   'date': '2015-12-31',
#   'beforeAfterMarket': 'AfterMarket',
#   'currency': 'USD',
#   'epsActual': 0.82,
#   'epsEstimate': 0.8075,
#   'epsDifference': 0.0125,
#   'surprisePercent': 1.548},
#  '2015-09-30': {'reportDate': '2015-10-27',
#   'date': '2015-09-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.49,
#   'epsEstimate': 0.47,
#   'epsDifference': 0.02,
#   'surprisePercent': 4.2553},
#  '2015-06-30': {'reportDate': '2015-07-21',
#   'date': '2015-06-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.4625,
#   'epsEstimate': 0.4525,
#   'epsDifference': 0.01,
#   'surprisePercent': 2.2099},
#  '2015-03-31': {'reportDate': '2015-04-27',
#   'date': '2015-03-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.5825,
#   'epsEstimate': 0.54,
#   'epsDifference': 0.0425,
#   'surprisePercent': 7.8704},
#  '2014-12-31': {'reportDate': '2015-01-27',
#   'date': '2014-12-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.765,
#   'epsEstimate': 0.65,
#   'epsDifference': 0.115,
#   'surprisePercent': 17.6923},
#  '2014-09-30': {'reportDate': '2014-10-20',
#   'date': '2014-09-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.355,
#   'epsEstimate': 0.3275,
#   'epsDifference': 0.0275,
#   'surprisePercent': 8.3969},
#  '2014-06-30': {'reportDate': '2014-07-22',
#   'date': '2014-06-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.32,
#   'epsEstimate': 0.3075,
#   'epsDifference': 0.0125,
#   'surprisePercent': 4.065},
#  '2014-03-31': {'reportDate': '2014-04-23',
#   'date': '2014-03-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.415,
#   'epsEstimate': 0.365,
#   'epsDifference': 0.05,
#   'surprisePercent': 13.6986},
#  '2013-12-31': {'reportDate': '2014-01-27',
#   'date': '2013-12-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.5175,
#   'epsEstimate': 0.5025,
#   'epsDifference': 0.015,
#   'surprisePercent': 2.9851},
#  '2013-09-30': {'reportDate': '2013-10-28',
#   'date': '2013-09-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.295,
#   'epsEstimate': 0.285,
#   'epsDifference': 0.01,
#   'surprisePercent': 3.5088},
#  '2013-06-30': {'reportDate': '2013-07-23',
#   'date': '2013-06-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.2675,
#   'epsEstimate': 0.2625,
#   'epsDifference': 0.005,
#   'surprisePercent': 1.9048},
#  '2013-03-31': {'reportDate': '2013-04-23',
#   'date': '2013-03-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.36,
#   'epsEstimate': 0.3575,
#   'epsDifference': 0.0025,
#   'surprisePercent': 0.6993},
#  '2012-12-31': {'reportDate': '2013-01-23',
#   'date': '2012-12-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.4925,
#   'epsEstimate': 0.48,
#   'epsDifference': 0.0125,
#   'surprisePercent': 2.6042},
#  '2012-09-30': {'reportDate': '2012-10-25',
#   'date': '2012-09-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.31,
#   'epsEstimate': 0.3125,
#   'epsDifference': -0.0025,
#   'surprisePercent': -0.8},
#  '2012-06-30': {'reportDate': '2012-07-24',
#   'date': '2012-06-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.3325,
#   'epsEstimate': 0.37,
#   'epsDifference': -0.0375,
#   'surprisePercent': -10.1351},
#  '2012-03-31': {'reportDate': '2012-04-24',
#   'date': '2012-03-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.44,
#   'epsEstimate': 0.3575,
#   'epsDifference': 0.0825,
#   'surprisePercent': 23.0769},
#  '2011-12-31': {'reportDate': '2012-01-24',
#   'date': '2011-12-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.495,
#   'epsEstimate': 0.3625,
#   'epsDifference': 0.1325,
#   'surprisePercent': 36.5517},
#  '2011-09-30': {'reportDate': '2011-10-18',
#   'date': '2011-09-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.2525,
#   'epsEstimate': 0.265,
#   'epsDifference': -0.0125,
#   'surprisePercent': -4.717},
#  '2011-06-30': {'reportDate': '2011-07-19',
#   'date': '2011-06-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.2775,
#   'epsEstimate': 0.2075,
#   'epsDifference': 0.07,
#   'surprisePercent': 33.7349},
#  '2011-03-31': {'reportDate': '2011-04-20',
#   'date': '2011-03-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.2275,
#   'epsEstimate': 0.1925,
#   'epsDifference': 0.035,
#   'surprisePercent': 18.1818},
#  '2010-12-31': {'reportDate': '2011-01-18',
#   'date': '2010-12-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.23,
#   'epsEstimate': 0.1925,
#   'epsDifference': 0.0375,
#   'surprisePercent': 19.4805},
#  '2010-09-30': {'reportDate': '2010-10-18',
#   'date': '2010-09-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.165,
#   'epsEstimate': 0.145,
#   'epsDifference': 0.02,
#   'surprisePercent': 13.7931},
#  '2010-06-30': {'reportDate': '2010-07-20',
#   'date': '2010-06-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.125,
#   'epsEstimate': 0.11,
#   'epsDifference': 0.015,
#   'surprisePercent': 13.6364},
#  '2010-03-31': {'reportDate': '2010-04-20',
#   'date': '2010-03-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.12,
#   'epsEstimate': 0.0875,
#   'epsDifference': 0.0325,
#   'surprisePercent': 37.1429},
#  '2009-12-31': {'reportDate': '2010-01-25',
#   'date': '2009-12-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.13,
#   'epsEstimate': 0.075,
#   'epsDifference': 0.055,
#   'surprisePercent': 73.3333},
#  '2009-09-30': {'reportDate': '2009-10-19',
#   'date': '2009-09-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.065,
#   'epsEstimate': 0.05,
#   'epsDifference': 0.015,
#   'surprisePercent': 30},
#  '2009-06-30': {'reportDate': '2009-07-21',
#   'date': '2009-06-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.0475,
#   'epsEstimate': 0.0425,
#   'epsDifference': 0.005,
#   'surprisePercent': 11.7647},
#  '2009-03-31': {'reportDate': '2009-04-22',
#   'date': '2009-03-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.0475,
#   'epsEstimate': 0.04,
#   'epsDifference': 0.0075,
#   'surprisePercent': 18.75},
#  '2008-12-31': {'reportDate': '2009-01-21',
#   'date': '2008-12-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.0625,
#   'epsEstimate': 0.05,
#   'epsDifference': 0.0125,
#   'surprisePercent': 25},
#  '2008-09-30': {'reportDate': '2008-10-21',
#   'date': '2008-09-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.045,
#   'epsEstimate': 0.04,
#   'epsDifference': 0.005,
#   'surprisePercent': 12.5},
#  '2008-06-30': {'reportDate': '2008-07-21',
#   'date': '2008-06-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.0425,
#   'epsEstimate': 0.0375,
#   'epsDifference': 0.005,
#   'surprisePercent': 13.3333},
#  '2008-03-31': {'reportDate': '2008-04-23',
#   'date': '2008-03-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.0425,
#   'epsEstimate': 0.0375,
#   'epsDifference': 0.005,
#   'surprisePercent': 13.3333},
#  '2007-12-31': {'reportDate': '2008-01-22',
#   'date': '2007-12-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.25,
#   'epsEstimate': 0.23,
#   'epsDifference': 0.02,
#   'surprisePercent': 8.6957},
#  '2007-09-30': {'reportDate': '2007-10-22',
#   'date': '2007-09-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.14,
#   'epsEstimate': 0.12,
#   'epsDifference': 0.02,
#   'surprisePercent': 16.6667},
#  '2007-06-30': {'reportDate': '2007-07-25',
#   'date': '2007-06-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.13,
#   'epsEstimate': 0.1,
#   'epsDifference': 0.03,
#   'surprisePercent': 30},
#  '2007-03-31': {'reportDate': '2007-04-25',
#   'date': '2007-03-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.12,
#   'epsEstimate': 0.09,
#   'epsDifference': 0.03,
#   'surprisePercent': 33.3333},
#  '2006-12-31': {'reportDate': '2007-01-17',
#   'date': '2006-12-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.16,
#   'epsEstimate': 0.11,
#   'epsDifference': 0.05,
#   'surprisePercent': 45.4545},
#  '2006-09-30': {'reportDate': '2006-10-18',
#   'date': '2006-09-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.09,
#   'epsEstimate': 0.07,
#   'epsDifference': 0.02,
#   'surprisePercent': 28.5714},
#  '2006-06-30': {'reportDate': '2006-07-19',
#   'date': '2006-06-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.08,
#   'epsEstimate': 0.06,
#   'epsDifference': 0.02,
#   'surprisePercent': 33.3333},
#  '2006-03-31': {'reportDate': '2006-04-19',
#   'date': '2006-03-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.07,
#   'epsEstimate': 0.06,
#   'epsDifference': 0.01,
#   'surprisePercent': 16.6667},
#  '2005-12-31': {'reportDate': '2006-01-18',
#   'date': '2005-12-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.09,
#   'epsEstimate': 0.09,
#   'epsDifference': 0,
#   'surprisePercent': 0},
#  '2005-09-30': {'reportDate': '2005-10-11',
#   'date': '2005-09-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.05,
#   'epsEstimate': 0.05,
#   'epsDifference': 0,
#   'surprisePercent': 0},
#  '2005-06-30': {'reportDate': '2005-07-13',
#   'date': '2005-06-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.05,
#   'epsEstimate': 0.04,
#   'epsDifference': 0.01,
#   'surprisePercent': 25},
#  '2005-03-31': {'reportDate': '2005-04-13',
#   'date': '2005-03-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.05,
#   'epsEstimate': 0.03,
#   'epsDifference': 0.02,
#   'surprisePercent': 66.6667},
#  '2004-12-31': {'reportDate': '2005-01-12',
#   'date': '2004-12-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.05,
#   'epsEstimate': 0.03,
#   'epsDifference': 0.02,
#   'surprisePercent': 66.6667},
#  '2004-09-30': {'reportDate': '2004-10-13',
#   'date': '2004-09-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.02,
#   'epsEstimate': 0.01,
#   'epsDifference': 0.01,
#   'surprisePercent': 100},
#  '2004-06-30': {'reportDate': '2004-07-14',
#   'date': '2004-06-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.01,
#   'epsEstimate': 0.01,
#   'epsDifference': 0,
#   'surprisePercent': 0},
#  '2004-03-31': {'reportDate': '2004-04-14',
#   'date': '2004-03-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.01,
#   'epsEstimate': 0.01,
#   'epsDifference': 0,
#   'surprisePercent': 0},
#  '2003-12-31': {'reportDate': '2004-01-14',
#   'date': '2003-12-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.01,
#   'epsEstimate': 0.01,
#   'epsDifference': 0,
#   'surprisePercent': 0},
#  '2003-09-30': {'reportDate': '2003-10-15',
#   'date': '2003-09-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.01,
#   'epsEstimate': None,
#   'epsDifference': None,
#   'surprisePercent': None},
#  '2003-06-30': {'reportDate': '2003-07-16',
#   'date': '2003-06-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.0009,
#   'epsEstimate': None,
#   'epsDifference': None,
#   'surprisePercent': None},
#  '2003-03-31': {'reportDate': '2003-04-16',
#   'date': '2003-03-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.0007,
#   'epsEstimate': None,
#   'epsDifference': None,
#   'surprisePercent': None},
#  '2002-12-31': {'reportDate': '2003-01-15',
#   'date': '2002-12-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': -0.0004,
#   'epsEstimate': None,
#   'epsDifference': None,
#   'surprisePercent': None},
#  '2002-09-30': {'reportDate': '2002-10-16',
#   'date': '2002-09-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': -0.0022,
#   'epsEstimate': None,
#   'epsDifference': None,
#   'surprisePercent': None},
#  '2002-06-30': {'reportDate': '2002-07-16',
#   'date': '2002-06-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.01,
#   'epsEstimate': 0.01,
#   'epsDifference': 0,
#   'surprisePercent': 0},
#  '2002-03-31': {'reportDate': '2002-04-18',
#   'date': '2002-03-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.002,
#   'epsEstimate': None,
#   'epsDifference': None,
#   'surprisePercent': None},
#  '2001-12-31': {'reportDate': '2002-01-16',
#   'date': '2001-12-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.01,
#   'epsEstimate': 0.01,
#   'epsDifference': 0,
#   'surprisePercent': 0},
#  '2001-09-30': {'reportDate': '2001-10-18',
#   'date': '2001-09-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.0034,
#   'epsEstimate': None,
#   'epsDifference': None,
#   'surprisePercent': None},
#  '2001-06-30': {'reportDate': '2001-07-18',
#   'date': '2001-06-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.003,
#   'epsEstimate': None,
#   'epsDifference': None,
#   'surprisePercent': None},
#  '2001-03-31': {'reportDate': '2001-04-18',
#   'date': '2001-03-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.01,
#   'epsEstimate': None,
#   'epsDifference': None,
#   'surprisePercent': None},
#  '2000-12-31': {'reportDate': '2000-12-31',
#   'date': '2000-12-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': -0.0103,
#   'epsEstimate': None,
#   'epsDifference': None,
#   'surprisePercent': None},
#  '2000-09-30': {'reportDate': '2000-09-30',
#   'date': '2000-09-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.0168,
#   'epsEstimate': None,
#   'epsDifference': None,
#   'surprisePercent': None},
#  '2000-06-30': {'reportDate': '2000-07-18',
#   'date': '2000-06-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.03,
#   'epsEstimate': 0.03,
#   'epsDifference': 0,
#   'surprisePercent': 0},
#  '2000-03-31': {'reportDate': '2000-04-19',
#   'date': '2000-03-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.03,
#   'epsEstimate': 0.03,
#   'epsDifference': 0,
#   'surprisePercent': 0},
#  '1999-12-31': {'reportDate': '2000-01-19',
#   'date': '1999-12-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.04,
#   'epsEstimate': 0.03,
#   'epsDifference': 0.01,
#   'surprisePercent': 33.3333},
#  '1999-09-30': {'reportDate': '1999-10-13',
#   'date': '1999-09-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.02,
#   'epsEstimate': 0.02,
#   'epsDifference': 0,
#   'surprisePercent': 0},
#  '1999-06-30': {'reportDate': '1999-07-14',
#   'date': '1999-06-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.02,
#   'epsEstimate': 0.02,
#   'epsDifference': 0,
#   'surprisePercent': 0},
#  '1999-03-31': {'reportDate': '1999-04-14',
#   'date': '1999-03-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.02,
#   'epsEstimate': 0.02,
#   'epsDifference': 0,
#   'surprisePercent': 0},
#  '1998-12-31': {'reportDate': '1999-01-13',
#   'date': '1998-12-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.03,
#   'epsEstimate': 0.02,
#   'epsDifference': 0.01,
#   'surprisePercent': 50},
#  '1998-09-30': {'reportDate': '1998-10-14',
#   'date': '1998-09-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.02,
#   'epsEstimate': 0.02,
#   'epsDifference': 0,
#   'surprisePercent': 0},
#  '1998-06-30': {'reportDate': '1998-07-15',
#   'date': '1998-06-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.02,
#   'epsEstimate': 0.01,
#   'epsDifference': 0.01,
#   'surprisePercent': 100},
#  '1998-03-31': {'reportDate': '1998-04-15',
#   'date': '1998-03-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.01,
#   'epsEstimate': 0.01,
#   'epsDifference': 0,
#   'surprisePercent': 0},
#  '1997-12-31': {'reportDate': '1998-01-14',
#   'date': '1997-12-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.01,
#   'epsEstimate': 0.01,
#   'epsDifference': 0,
#   'surprisePercent': 0},
#  '1997-09-30': {'reportDate': '1997-09-30',
#   'date': '1997-09-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': -0.0114,
#   'epsEstimate': None,
#   'epsDifference': None,
#   'surprisePercent': None},
#  '1997-06-30': {'reportDate': '1997-07-16',
#   'date': '1997-06-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': -0.02,
#   'epsEstimate': -0.02,
#   'epsDifference': 0,
#   'surprisePercent': 0},
#  '1997-03-31': {'reportDate': '1997-04-16',
#   'date': '1997-03-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': -0.05,
#   'epsEstimate': -0.04,
#   'epsDifference': -0.01,
#   'surprisePercent': -25},
#  '1996-12-31': {'reportDate': '1997-01-15',
#   'date': '1996-12-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': -0.03,
#   'epsEstimate': -0.02,
#   'epsDifference': -0.01,
#   'surprisePercent': -50},
#  '1996-09-30': {'reportDate': '1996-10-16',
#   'date': '1996-09-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.0018,
#   'epsEstimate': -0.01,
#   'epsDifference': 0.0118,
#   'surprisePercent': 118},
#  '1996-06-30': {'reportDate': '1996-07-17',
#   'date': '1996-06-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': -0.02,
#   'epsEstimate': -0.04,
#   'epsDifference': 0.02,
#   'surprisePercent': 50},
#  '1996-03-31': {'reportDate': '1996-04-17',
#   'date': '1996-03-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': -0.07,
#   'epsEstimate': -0.05,
#   'epsDifference': -0.02,
#   'surprisePercent': -40},
#  '1995-12-31': {'reportDate': '1996-01-17',
#   'date': '1995-12-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': -0.02,
#   'epsEstimate': -0.01,
#   'epsDifference': -0.01,
#   'surprisePercent': -100},
#  '1995-09-30': {'reportDate': '1995-10-18',
#   'date': '1995-09-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.02,
#   'epsEstimate': 0.02,
#   'epsDifference': 0,
#   'surprisePercent': 0},
#  '1995-06-30': {'reportDate': '1995-07-20',
#   'date': '1995-06-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.03,
#   'epsEstimate': 0.03,
#   'epsDifference': 0,
#   'surprisePercent': 0},
#  '1995-03-31': {'reportDate': '1995-04-20',
#   'date': '1995-03-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.02,
#   'epsEstimate': 0.03,
#   'epsDifference': -0.01,
#   'surprisePercent': -33.3333},
#  '1994-12-31': {'reportDate': '1995-01-19',
#   'date': '1994-12-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.05,
#   'epsEstimate': 0.04,
#   'epsDifference': 0.01,
#   'surprisePercent': 25},
#  '1994-09-30': {'reportDate': '1994-10-17',
#   'date': '1994-09-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.03,
#   'epsEstimate': 0.03,
#   'epsDifference': 0,
#   'surprisePercent': 0},
#  '1994-06-30': {'reportDate': '1994-06-30',
#   'date': '1994-06-30',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.0104,
#   'epsEstimate': None,
#   'epsDifference': None,
#   'surprisePercent': None},
#  '1994-03-31': {'reportDate': '1994-03-31',
#   'date': '1994-03-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.0104,
#   'epsEstimate': None,
#   'epsDifference': None,
#   'surprisePercent': None},
#  '1993-12-31': {'reportDate': '1993-12-31',
#   'date': '1993-12-31',
#   'beforeAfterMarket': None,
#   'currency': 'USD',
#   'epsActual': 0.0031,
#   'epsEstimate': None,
#   'epsDifference': None,
#   'surprisePercent': None}}

# %%
payload['Earnings']['Trend']
# Out:
# {'2022-09-30': {'date': '2022-09-30',
#   'period': '+1y',
#   'growth': '0.0160',
#   'earningsEstimateAvg': '5.6800',
#   'earningsEstimateLow': '5.0500',
#   'earningsEstimateHigh': '6.3300',
#   'earningsEstimateYearAgoEps': '5.5900',
#   'earningsEstimateNumberOfAnalysts': '40.0000',
#   'earningsEstimateGrowth': '0.0160',
#   'revenueEstimateAvg': '380824000000.00',
#   'revenueEstimateLow': '354026000000.00',
#   'revenueEstimateHigh': '399858000000.00',
#   'revenueEstimateYearAgoEps': None,
#   'revenueEstimateNumberOfAnalysts': '39.00',
#   'revenueEstimateGrowth': '0.0390',
#   'epsTrendCurrent': '5.6800',
#   'epsTrend7daysAgo': '5.6800',
#   'epsTrend30daysAgo': '5.6700',
#   'epsTrend60daysAgo': '5.5800',
#   'epsTrend90daysAgo': '5.3400',
#   'epsRevisionsUpLast7days': '1.0000',
#   'epsRevisionsUpLast30days': '6.0000',
#   'epsRevisionsDownLast30days': '0.0000',
#   'epsRevisionsDownLast90days': None},
#  '2021-12-31': {'date': '2021-12-31',
#   'period': '+1q',
#   'growth': '0.1130',
#   'earningsEstimateAvg': '1.8700',
#   'earningsEstimateLow': '1.6800',
#   'earningsEstimateHigh': '2.0900',
#   'earningsEstimateYearAgoEps': '1.6800',
#   'earningsEstimateNumberOfAnalysts': '22.0000',
#   'earningsEstimateGrowth': '0.1130',
#   'revenueEstimateAvg': '119796000000.00',
#   'revenueEstimateLow': '110108000000.00',
#   'revenueEstimateHigh': '126431000000.00',
#   'revenueEstimateYearAgoEps': None,
#   'revenueEstimateNumberOfAnalysts': '19.00',
#   'revenueEstimateGrowth': None,
#   'epsTrendCurrent': '1.8700',
#   'epsTrend7daysAgo': '1.8700',
#   'epsTrend30daysAgo': '1.8700',
#   'epsTrend60daysAgo': '1.8700',
#   'epsTrend90daysAgo': '1.8100',
#   'epsRevisionsUpLast7days': '1.0000',
#   'epsRevisionsUpLast30days': '3.0000',
#   'epsRevisionsDownLast30days': '0.0000',
#   'epsRevisionsDownLast90days': None},
#  '2021-09-30': {'date': '2021-09-30',
#   'period': '0y',
#   'growth': '0.7040',
#   'earningsEstimateAvg': '5.5900',
#   'earningsEstimateLow': '5.3800',
#   'earningsEstimateHigh': '5.7300',
#   'earningsEstimateYearAgoEps': '3.2800',
#   'earningsEstimateNumberOfAnalysts': '41.0000',
#   'earningsEstimateGrowth': '0.7040',
#   'revenueEstimateAvg': '366492000000.00',
#   'revenueEstimateLow': '356159000000.00',
#   'revenueEstimateHigh': '371868000000.00',
#   'revenueEstimateYearAgoEps': None,
#   'revenueEstimateNumberOfAnalysts': '39.00',
#   'revenueEstimateGrowth': '0.3350',
#   'epsTrendCurrent': '5.5900',
#   'epsTrend7daysAgo': '5.5900',
#   'epsTrend30daysAgo': '5.5800',
#   'epsTrend60daysAgo': '5.4900',
#   'epsTrend90daysAgo': '5.1800',
#   'epsRevisionsUpLast7days': '1.0000',
#   'epsRevisionsUpLast30days': '4.0000',
#   'epsRevisionsDownLast30days': '0.0000',
#   'epsRevisionsDownLast90days': None},
#  '2021-06-30': {'date': '2021-06-30',
#   'period': '0q',
#   'growth': '0.5620',
#   'earningsEstimateAvg': '1.0000',
#   'earningsEstimateLow': '0.8200',
#   'earningsEstimateHigh': '1.1600',
#   'earningsEstimateYearAgoEps': '0.6400',
#   'earningsEstimateNumberOfAnalysts': '28.0000',
#   'earningsEstimateGrowth': '0.5620',
#   'revenueEstimateAvg': '72927700000.00',
#   'revenueEstimateLow': '65682000000.00',
#   'revenueEstimateHigh': '77150000000.00',
#   'revenueEstimateYearAgoEps': None,
#   'revenueEstimateNumberOfAnalysts': '25.00',
#   'revenueEstimateGrowth': '0.2220',
#   'epsTrendCurrent': '1.0000',
#   'epsTrend7daysAgo': '0.9900',
#   'epsTrend30daysAgo': '0.9900',
#   'epsTrend60daysAgo': '0.9900',
#   'epsTrend90daysAgo': '0.8200',
#   'epsRevisionsUpLast7days': '2.0000',
#   'epsRevisionsUpLast30days': '3.0000',
#   'epsRevisionsDownLast30days': '0.0000',
#   'epsRevisionsDownLast90days': None},
#  '2021-03-31': {'date': '2021-03-31',
#   'period': '0q',
#   'growth': '0.5470',
#   'earningsEstimateAvg': '0.9900',
#   'earningsEstimateLow': '0.8500',
#   'earningsEstimateHigh': '1.0900',
#   'earningsEstimateYearAgoEps': '0.6400',
#   'earningsEstimateNumberOfAnalysts': '29.0000',
#   'earningsEstimateGrowth': '0.5470',
#   'revenueEstimateAvg': '77354900000.00',
#   'revenueEstimateLow': '70790900000.00',
#   'revenueEstimateHigh': '83193000000.00',
#   'revenueEstimateYearAgoEps': None,
#   'revenueEstimateNumberOfAnalysts': '27.00',
#   'revenueEstimateGrowth': '0.3270',
#   'epsTrendCurrent': '0.9900',
#   'epsTrend7daysAgo': '0.9800',
#   'epsTrend30daysAgo': '0.9800',
#   'epsTrend60daysAgo': '0.9800',
#   'epsTrend90daysAgo': '0.9100',
#   'epsRevisionsUpLast7days': '1.0000',
#   'epsRevisionsUpLast30days': '4.0000',
#   'epsRevisionsDownLast30days': '0.0000',
#   'epsRevisionsDownLast90days': None},
#  '2020-12-31': {'date': '2020-12-31',
#   'period': '0q',
#   'growth': '0.1280',
#   'earningsEstimateAvg': '1.4100',
#   'earningsEstimateLow': '1.2300',
#   'earningsEstimateHigh': '1.5600',
#   'earningsEstimateYearAgoEps': '1.2500',
#   'earningsEstimateNumberOfAnalysts': '30.0000',
#   'earningsEstimateGrowth': '0.1280',
#   'revenueEstimateAvg': '103276000000.00',
#   'revenueEstimateLow': '97967000000.00',
#   'revenueEstimateHigh': '110122000000.00',
#   'revenueEstimateYearAgoEps': None,
#   'revenueEstimateNumberOfAnalysts': '27.00',
#   'revenueEstimateGrowth': '0.1670',
#   'epsTrendCurrent': '1.4100',
#   'epsTrend7daysAgo': '1.4000',
#   'epsTrend30daysAgo': '1.3900',
#   'epsTrend60daysAgo': '1.3900',
#   'epsTrend90daysAgo': '1.3700',
#   'epsRevisionsUpLast7days': '2.0000',
#   'epsRevisionsUpLast30days': '9.0000',
#   'epsRevisionsDownLast30days': '2.0000',
#   'epsRevisionsDownLast90days': None},
#  '2020-09-30': {'date': '2020-09-30',
#   'period': '0y',
#   'growth': '0.0910',
#   'earningsEstimateAvg': '3.2400',
#   'earningsEstimateLow': '3.0800',
#   'earningsEstimateHigh': '3.4000',
#   'earningsEstimateYearAgoEps': '2.9700',
#   'earningsEstimateNumberOfAnalysts': '37.0000',
#   'earningsEstimateGrowth': '0.0910',
#   'revenueEstimateAvg': '273223000000.00',
#   'revenueEstimateLow': '262362000000.00',
#   'revenueEstimateHigh': '280364000000.00',
#   'revenueEstimateYearAgoEps': None,
#   'revenueEstimateNumberOfAnalysts': '34.00',
#   'revenueEstimateGrowth': '0.0500',
#   'epsTrendCurrent': '3.2400',
#   'epsTrend7daysAgo': '3.2400',
#   'epsTrend30daysAgo': '3.2400',
#   'epsTrend60daysAgo': '12.9600',
#   'epsTrend90daysAgo': '12.4300',
#   'epsRevisionsUpLast7days': '2.0000',
#   'epsRevisionsUpLast30days': '6.0000',
#   'epsRevisionsDownLast30days': '3.0000',
#   'epsRevisionsDownLast90days': None},
#  '2020-06-30': {'date': '2020-06-30',
#   'period': '0q',
#   'growth': '-0.0640',
#   'earningsEstimateAvg': '2.0400',
#   'earningsEstimateLow': '1.6700',
#   'earningsEstimateHigh': '2.4700',
#   'earningsEstimateYearAgoEps': '2.1800',
#   'earningsEstimateNumberOfAnalysts': '31.0000',
#   'earningsEstimateGrowth': '-0.0640',
#   'revenueEstimateAvg': '52247700000.00',
#   'revenueEstimateLow': '48955000000.00',
#   'revenueEstimateHigh': '55838000000.00',
#   'revenueEstimateYearAgoEps': None,
#   'revenueEstimateNumberOfAnalysts': '27.00',
#   'revenueEstimateGrowth': '-0.0290',
#   'epsTrendCurrent': '2.0400',
#   'epsTrend7daysAgo': '2.0200',
#   'epsTrend30daysAgo': '2.0000',
#   'epsTrend60daysAgo': '2.0000',
#   'epsTrend90daysAgo': '2.0700',
#   'epsRevisionsUpLast7days': '4.0000',
#   'epsRevisionsUpLast30days': '10.0000',
#   'epsRevisionsDownLast30days': '0.0000',
#   'epsRevisionsDownLast90days': None},
#  '2020-03-31': {'date': '2020-03-31',
#   'period': '0q',
#   'growth': '-0.0810',
#   'earningsEstimateAvg': '2.2600',
#   'earningsEstimateLow': '1.5200',
#   'earningsEstimateHigh': '2.7300',
#   'earningsEstimateYearAgoEps': '2.4600',
#   'earningsEstimateNumberOfAnalysts': '29.0000',
#   'earningsEstimateGrowth': '-0.0810',
#   'revenueEstimateAvg': '54544400000.00',
#   'revenueEstimateLow': '46272700000.00',
#   'revenueEstimateHigh': '60724000000.00',
#   'revenueEstimateYearAgoEps': None,
#   'revenueEstimateNumberOfAnalysts': '25.00',
#   'revenueEstimateGrowth': None,
#   'epsTrendCurrent': '2.2600',
#   'epsTrend7daysAgo': '2.2800',
#   'epsTrend30daysAgo': '2.4200',
#   'epsTrend60daysAgo': '2.7200',
#   'epsTrend90daysAgo': '3.0000',
#   'epsRevisionsUpLast7days': '2.0000',
#   'epsRevisionsUpLast30days': '2.0000',
#   'epsRevisionsDownLast30days': '3.0000',
#   'epsRevisionsDownLast90days': None},
#  '2019-12-31': {'date': '2019-12-31',
#   'period': '0q',
#   'growth': '0.0890',
#   'earningsEstimateAvg': '4.5500',
#   'earningsEstimateLow': '4.3700',
#   'earningsEstimateHigh': '4.8300',
#   'earningsEstimateYearAgoEps': '4.1800',
#   'earningsEstimateNumberOfAnalysts': '34.0000',
#   'earningsEstimateGrowth': '0.0890',
#   'revenueEstimateAvg': '88496400000.00',
#   'revenueEstimateLow': '86754500000.00',
#   'revenueEstimateHigh': '91678000000.00',
#   'revenueEstimateYearAgoEps': None,
#   'revenueEstimateNumberOfAnalysts': '31.00',
#   'revenueEstimateGrowth': None,
#   'epsTrendCurrent': '4.5500',
#   'epsTrend7daysAgo': '4.5400',
#   'epsTrend30daysAgo': '4.5300',
#   'epsTrend60daysAgo': '4.5000',
#   'epsTrend90daysAgo': '4.4500',
#   'epsRevisionsUpLast7days': '2.0000',
#   'epsRevisionsUpLast30days': '10.0000',
#   'epsRevisionsDownLast30days': '0.0000',
#   'epsRevisionsDownLast90days': None},
#  '2019-09-30': {'date': '2019-09-30',
#   'period': '0y',
#   'growth': '-0.0190',
#   'earningsEstimateAvg': '11.6800',
#   'earningsEstimateLow': '11.5000',
#   'earningsEstimateHigh': '11.8000',
#   'earningsEstimateYearAgoEps': '11.9100',
#   'earningsEstimateNumberOfAnalysts': '40.0000',
#   'earningsEstimateGrowth': '-0.0190',
#   'revenueEstimateAvg': '259042000000.00',
#   'revenueEstimateLow': '256663000000.00',
#   'revenueEstimateHigh': '260711000000.00',
#   'revenueEstimateYearAgoEps': None,
#   'revenueEstimateNumberOfAnalysts': '41.00',
#   'revenueEstimateGrowth': '-0.0250',
#   'epsTrendCurrent': '11.6800',
#   'epsTrend7daysAgo': '11.6700',
#   'epsTrend30daysAgo': '11.6600',
#   'epsTrend60daysAgo': '11.6700',
#   'epsTrend90daysAgo': '11.5800',
#   'epsRevisionsUpLast7days': '4.0000',
#   'epsRevisionsUpLast30days': '14.0000',
#   'epsRevisionsDownLast30days': '0.0000',
#   'epsRevisionsDownLast90days': None},
#  '2019-06-30': {'date': '2019-06-30',
#   'period': '0q',
#   'growth': '-0.1030',
#   'earningsEstimateAvg': '2.1000',
#   'earningsEstimateLow': '1.7900',
#   'earningsEstimateHigh': '2.2000',
#   'earningsEstimateYearAgoEps': '2.3400',
#   'earningsEstimateNumberOfAnalysts': '36.0000',
#   'earningsEstimateGrowth': '-0.1030',
#   'revenueEstimateAvg': '53392100000.00',
#   'revenueEstimateLow': '52000000000.00',
#   'revenueEstimateHigh': '54217100000.00',
#   'revenueEstimateYearAgoEps': None,
#   'revenueEstimateNumberOfAnalysts': '33.00',
#   'revenueEstimateGrowth': '0.0020',
#   'epsTrendCurrent': '2.1000',
#   'epsTrend7daysAgo': '2.1000',
#   'epsTrend30daysAgo': '2.1000',
#   'epsTrend60daysAgo': '2.1000',
#   'epsTrend90daysAgo': '2.0700',
#   'epsRevisionsUpLast7days': '1.0000',
#   'epsRevisionsUpLast30days': '3.0000',
#   'epsRevisionsDownLast30days': '0.0000',
#   'epsRevisionsDownLast90days': None},
#  '2019-03-31': {'date': '2019-03-31',
#   'period': '0q',
#   'growth': '-0.1360',
#   'earningsEstimateAvg': '2.3600',
#   'earningsEstimateLow': '2.1200',
#   'earningsEstimateHigh': '2.4900',
#   'earningsEstimateYearAgoEps': '2.7300',
#   'earningsEstimateNumberOfAnalysts': '32.0000',
#   'earningsEstimateGrowth': '-0.1360',
#   'revenueEstimateAvg': '57372400000.00',
#   'revenueEstimateLow': '54511000000.00',
#   'revenueEstimateHigh': '58983900000.00',
#   'revenueEstimateYearAgoEps': None,
#   'revenueEstimateNumberOfAnalysts': '28.00',
#   'revenueEstimateGrowth': '-0.0620',
#   'epsTrendCurrent': '2.3600',
#   'epsTrend7daysAgo': '2.3600',
#   'epsTrend30daysAgo': '2.3700',
#   'epsTrend60daysAgo': '2.3700',
#   'epsTrend90daysAgo': '2.6400',
#   'epsRevisionsUpLast7days': '1.0000',
#   'epsRevisionsUpLast30days': '4.0000',
#   'epsRevisionsDownLast30days': '1.0000',
#   'epsRevisionsDownLast90days': None},
#  '2018-12-31': {'date': '2018-12-31',
#   'period': '0q',
#   'growth': '0.0720',
#   'earningsEstimateAvg': '4.1700',
#   'earningsEstimateLow': '4.1300',
#   'earningsEstimateHigh': '4.2700',
#   'earningsEstimateYearAgoEps': '3.8900',
#   'earningsEstimateNumberOfAnalysts': '33.0000',
#   'earningsEstimateGrowth': '0.0720',
#   'revenueEstimateAvg': '83997900000.00',
#   'revenueEstimateLow': '83056000000.00',
#   'revenueEstimateHigh': '84586500000.00',
#   'revenueEstimateYearAgoEps': None,
#   'revenueEstimateNumberOfAnalysts': '31.00',
#   'revenueEstimateGrowth': '-0.0490',
#   'epsTrendCurrent': '4.1700',
#   'epsTrend7daysAgo': '4.1700',
#   'epsTrend30daysAgo': '4.6500',
#   'epsTrend60daysAgo': '4.7100',
#   'epsTrend90daysAgo': '4.7500',
#   'epsRevisionsUpLast7days': '0.0000',
#   'epsRevisionsUpLast30days': '0.0000',
#   'epsRevisionsDownLast30days': '3.0000',
#   'epsRevisionsDownLast90days': None},
#  '2018-09-30': {'date': '2018-09-30',
#   'period': '0y',
#   'growth': '0.2800',
#   'earningsEstimateAvg': '11.7900',
#   'earningsEstimateLow': '11.4900',
#   'earningsEstimateHigh': '12.5000',
#   'earningsEstimateYearAgoEps': '9.2100',
#   'earningsEstimateNumberOfAnalysts': '42.0000',
#   'earningsEstimateGrowth': '0.2800',
#   'revenueEstimateAvg': '264031000000.00',
#   'revenueEstimateLow': '255916000000.00',
#   'revenueEstimateHigh': '266100000000.00',
#   'revenueEstimateYearAgoEps': None,
#   'revenueEstimateNumberOfAnalysts': '39.00',
#   'revenueEstimateGrowth': '0.1520',
#   'epsTrendCurrent': '11.7900',
#   'epsTrend7daysAgo': '11.7800',
#   'epsTrend30daysAgo': '11.7800',
#   'epsTrend60daysAgo': '11.7500',
#   'epsTrend90daysAgo': '11.7200',
#   'epsRevisionsUpLast7days': '3.0000',
#   'epsRevisionsUpLast30days': '6.0000',
#   'epsRevisionsDownLast30days': '0.0000',
#   'epsRevisionsDownLast90days': None},
#  '2018-06-30': {'date': '2018-06-30',
#   'period': '0q',
#   'growth': '0.3050',
#   'earningsEstimateAvg': '2.1800',
#   'earningsEstimateLow': '2.1000',
#   'earningsEstimateHigh': '2.2800',
#   'earningsEstimateYearAgoEps': '1.6700',
#   'earningsEstimateNumberOfAnalysts': '31.0000',
#   'earningsEstimateGrowth': '0.3050',
#   'revenueEstimateAvg': '52335600000.00',
#   'revenueEstimateLow': '49000000000.00',
#   'revenueEstimateHigh': '53490000000.00',
#   'revenueEstimateYearAgoEps': None,
#   'revenueEstimateNumberOfAnalysts': '29.00',
#   'revenueEstimateGrowth': '0.1530',
#   'epsTrendCurrent': '2.1800',
#   'epsTrend7daysAgo': '2.1800',
#   'epsTrend30daysAgo': '2.1800',
#   'epsTrend60daysAgo': '2.1800',
#   'epsTrend90daysAgo': '2.1100',
#   'epsRevisionsUpLast7days': '0.0000',
#   'epsRevisionsUpLast30days': '4.0000',
#   'epsRevisionsDownLast30days': '0.0000',
#   'epsRevisionsDownLast90days': None},
#  '2018-03-31': {'date': '2018-03-31',
#   'period': '0q',
#   'growth': '0.2810',
#   'earningsEstimateAvg': '2.6900',
#   'earningsEstimateLow': '2.5100',
#   'earningsEstimateHigh': '2.8000',
#   'earningsEstimateYearAgoEps': '2.1000',
#   'earningsEstimateNumberOfAnalysts': '32.0000',
#   'earningsEstimateGrowth': '0.2810',
#   'revenueEstimateAvg': '60975000000.00',
#   'revenueEstimateLow': '58269000000.00',
#   'revenueEstimateHigh': '62367000000.00',
#   'revenueEstimateYearAgoEps': None,
#   'revenueEstimateNumberOfAnalysts': '31.00',
#   'revenueEstimateGrowth': '0.1530',
#   'epsTrendCurrent': '2.6900',
#   'epsTrend7daysAgo': '2.7000',
#   'epsTrend30daysAgo': '2.7100',
#   'epsTrend60daysAgo': '2.7100',
#   'epsTrend90daysAgo': '2.9100',
#   'epsRevisionsUpLast7days': '0.0000',
#   'epsRevisionsUpLast30days': '1.0000',
#   'epsRevisionsDownLast30days': '3.0000',
#   'epsRevisionsDownLast90days': None},
#  '2017-12-31': {'date': '2017-12-31',
#   'period': '0q',
#   'growth': '0.1490',
#   'earningsEstimateAvg': '3.8600',
#   'earningsEstimateLow': '3.6800',
#   'earningsEstimateHigh': '4.1200',
#   'earningsEstimateYearAgoEps': '3.3600',
#   'earningsEstimateNumberOfAnalysts': '30.0000',
#   'earningsEstimateGrowth': '0.1490',
#   'revenueEstimateAvg': '87282800000.00',
#   'revenueEstimateLow': '84007100000.00',
#   'revenueEstimateHigh': '91088000000.00',
#   'revenueEstimateYearAgoEps': None,
#   'revenueEstimateNumberOfAnalysts': '30.00',
#   'revenueEstimateGrowth': '0.1140',
#   'epsTrendCurrent': '3.8600',
#   'epsTrend7daysAgo': '3.8000',
#   'epsTrend30daysAgo': '3.7700',
#   'epsTrend60daysAgo': '3.7700',
#   'epsTrend90daysAgo': '3.7700',
#   'epsRevisionsUpLast7days': '9.0000',
#   'epsRevisionsUpLast30days': '15.0000',
#   'epsRevisionsDownLast30days': '0.0000',
#   'epsRevisionsDownLast90days': None},
#  '2017-09-30': {'date': '2017-09-30',
#   'period': '0y',
#   'growth': '0.0830',
#   'earningsEstimateAvg': '9.0000',
#   'earningsEstimateLow': '8.9100',
#   'earningsEstimateHigh': '9.1500',
#   'earningsEstimateYearAgoEps': '8.3100',
#   'earningsEstimateNumberOfAnalysts': '34.0000',
#   'earningsEstimateGrowth': '0.0830',
#   'revenueEstimateAvg': '227414000000.00',
#   'revenueEstimateLow': '225105000000.00',
#   'revenueEstimateHigh': '229750000000.00',
#   'revenueEstimateYearAgoEps': None,
#   'revenueEstimateNumberOfAnalysts': '32.00',
#   'revenueEstimateGrowth': '0.0550',
#   'epsTrendCurrent': '9.0000',
#   'epsTrend7daysAgo': '9.0100',
#   'epsTrend30daysAgo': '9.0100',
#   'epsTrend60daysAgo': '9.0200',
#   'epsTrend90daysAgo': '8.8700',
#   'epsRevisionsUpLast7days': '0.0000',
#   'epsRevisionsUpLast30days': '2.0000',
#   'epsRevisionsDownLast30days': '0.0000',
#   'epsRevisionsDownLast90days': None},
#  '2017-06-30': {'date': '2017-06-30',
#   'period': '0q',
#   'growth': '0.1060',
#   'earningsEstimateAvg': '1.5700',
#   'earningsEstimateLow': '1.5000',
#   'earningsEstimateHigh': '1.6400',
#   'earningsEstimateYearAgoEps': '1.4200',
#   'earningsEstimateNumberOfAnalysts': '38.0000',
#   'earningsEstimateGrowth': '0.1060',
#   'revenueEstimateAvg': '44885600000.00',
#   'revenueEstimateLow': '43205000000.00',
#   'revenueEstimateHigh': '46134000000.00',
#   'revenueEstimateYearAgoEps': None,
#   'revenueEstimateNumberOfAnalysts': '36.00',
#   'revenueEstimateGrowth': '0.0600',
#   'epsTrendCurrent': '1.5700',
#   'epsTrend7daysAgo': '1.5700',
#   'epsTrend30daysAgo': '1.5700',
#   'epsTrend60daysAgo': '1.5700',
#   'epsTrend90daysAgo': '1.6200',
#   'epsRevisionsUpLast7days': '2.0000',
#   'epsRevisionsUpLast30days': '4.0000',
#   'epsRevisionsDownLast30days': '1.0000',
#   'epsRevisionsDownLast90days': None}}

# %%
payload['Earnings']['Annual']
# Out:
# {'2021-09-30': {'date': '2021-09-30', 'epsActual': 4.38},
#  '2020-09-30': {'date': '2020-09-30', 'epsActual': 3.27},
#  '2019-09-30': {'date': '2019-09-30', 'epsActual': 2.98},
#  '2018-09-30': {'date': '2018-09-30', 'epsActual': 2.97},
#  '2017-09-30': {'date': '2017-09-30', 'epsActual': 2.3},
#  '2016-09-30': {'date': '2016-09-30', 'epsActual': 2.0675},
#  '2015-09-30': {'date': '2015-09-30', 'epsActual': 2.3},
#  '2014-09-30': {'date': '2014-09-30', 'epsActual': 1.6075},
#  '2013-09-30': {'date': '2013-09-30', 'epsActual': 1.415},
#  '2012-09-30': {'date': '2012-09-30', 'epsActual': 1.5775},
#  '2011-09-30': {'date': '2011-09-30', 'epsActual': 0.9875},
#  '2010-09-30': {'date': '2010-09-30', 'epsActual': 0.54},
#  '2009-09-30': {'date': '2009-09-30', 'epsActual': 0.2225},
#  '2008-09-30': {'date': '2008-09-30', 'epsActual': 0.38},
#  '2007-09-30': {'date': '2007-09-30', 'epsActual': 0.55},
#  '2006-09-30': {'date': '2006-09-30', 'epsActual': 0.33},
#  '2005-09-30': {'date': '2005-09-30', 'epsActual': 0.2},
#  '2004-09-30': {'date': '2004-09-30', 'epsActual': 0.05},
#  '2003-09-30': {'date': '2003-09-30', 'epsActual': 0.0112},
#  '2002-09-30': {'date': '2002-09-30', 'epsActual': 0.0198},
#  '2001-09-30': {'date': '2001-09-30', 'epsActual': 0.0061},
#  '2000-09-30': {'date': '2000-09-30', 'epsActual': 0.1168},
#  '1999-09-30': {'date': '1999-09-30', 'epsActual': 0.09},
#  '1998-09-30': {'date': '1998-09-30', 'epsActual': 0.06},
#  '1997-09-30': {'date': '1997-09-30', 'epsActual': -0.1114},
#  '1996-09-30': {'date': '1996-09-30', 'epsActual': -0.1082},
#  '1995-09-30': {'date': '1995-09-30', 'epsActual': 0.12},
#  '1994-09-30': {'date': '1994-09-30', 'epsActual': 0.0539}}

# %% [markdown]
# ### Summary of the "Earnings" payload
#
# - **Earnings history**: this includes the history of both estimated EPS and actual EPS
# - **Earnings trend**: this includes the range of both earnings and revenue estimates, the number of analysts providing that range. The estimates are available for two different time horizons - +1 year and +1 quarter.

# %% [markdown]
# ### <font color=blue>Check what's in the "Financials" payload</font>

# %%
payload['Financials'].keys()
# Out:
# dict_keys(['Balance_Sheet', 'Cash_Flow', 'Income_Statement'])

# %% [markdown]
# #### Income statement

# %%
payload['Financials']['Income_Statement'].keys()
# Out:
# dict_keys(['currency_symbol', 'quarterly', 'yearly'])

# %%
payload['Financials']['Income_Statement']['yearly']['2020-09-30'].keys()
# Out:
# dict_keys(['date', 'filing_date', 'currency_symbol', 'researchDevelopment', 'effectOfAccountingCharges', 'incomeBeforeTax', 'minorityInterest', 'netIncome', 'sellingGeneralAdministrative', 'sellingAndMarketingExpenses', 'grossProfit', 'reconciledDepreciation', 'ebit', 'ebitda', 'depreciationAndAmortization', 'nonOperatingIncomeNetOther', 'operatingIncome', 'otherOperatingExpenses', 'interestExpense', 'taxProvision', 'interestIncome', 'netInterestIncome', 'extraordinaryItems', 'nonRecurring', 'otherItems', 'incomeTaxExpense', 'totalRevenue', 'totalOperatingExpenses', 'costOfRevenue', 'totalOtherIncomeExpenseNet', 'discontinuedOperations', 'netIncomeFromContinuingOps', 'netIncomeApplicableToCommonShares', 'preferredStockAndOtherAdjustments'])

# %%
payload['Financials']['Income_Statement']['yearly']
# Out:
# {'2020-09-30': {'date': '2020-09-30',
#   'filing_date': '2020-10-30',
#   'currency_symbol': 'USD',
#   'researchDevelopment': '18752000000.00',
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '67091000000.00',
#   'minorityInterest': None,
#   'netIncome': '57411000000.00',
#   'sellingGeneralAdministrative': '19916000000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '104956000000.00',
#   'reconciledDepreciation': '11056000000.00',
#   'ebit': '69964000000.00',
#   'ebitda': '81020000000.00',
#   'depreciationAndAmortization': '11056000000.00',
#   'nonOperatingIncomeNetOther': None,
#   'operatingIncome': '66288000000.00',
#   'otherOperatingExpenses': '208227000000.00',
#   'interestExpense': '2873000000.00',
#   'taxProvision': '9680000000.00',
#   'interestIncome': '3763000000.00',
#   'netInterestIncome': '890000000.00',
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '9680000000.00',
#   'totalRevenue': '274515000000.00',
#   'totalOperatingExpenses': '38668000000.00',
#   'costOfRevenue': '169559000000.00',
#   'totalOtherIncomeExpenseNet': '-803000000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': '57411000000.00',
#   'netIncomeApplicableToCommonShares': '57411000000.00',
#   'preferredStockAndOtherAdjustments': None},
#  '2019-09-30': {'date': '2019-09-30',
#   'filing_date': '2019-10-31',
#   'currency_symbol': 'USD',
#   'researchDevelopment': '16217000000.00',
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '65737000000.00',
#   'minorityInterest': None,
#   'netIncome': '55256000000.00',
#   'sellingGeneralAdministrative': '18245000000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '98392000000.00',
#   'reconciledDepreciation': '12547000000.00',
#   'ebit': '69313000000.00',
#   'ebitda': '81860000000.00',
#   'depreciationAndAmortization': '12547000000.00',
#   'nonOperatingIncomeNetOther': '1807000000.00',
#   'operatingIncome': '63930000000.00',
#   'otherOperatingExpenses': '196244000000.00',
#   'interestExpense': '3576000000.00',
#   'taxProvision': '10481000000.00',
#   'interestIncome': '4961000000.00',
#   'netInterestIncome': '1385000000.00',
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '10481000000.00',
#   'totalRevenue': '260174000000.00',
#   'totalOperatingExpenses': '34462000000.00',
#   'costOfRevenue': '161782000000.00',
#   'totalOtherIncomeExpenseNet': '-1807000000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': '55256000000.00',
#   'netIncomeApplicableToCommonShares': '55256000000.00',
#   'preferredStockAndOtherAdjustments': None},
#  '2018-09-30': {'date': '2018-09-30',
#   'filing_date': '2018-11-05',
#   'currency_symbol': 'USD',
#   'researchDevelopment': '14236000000.00',
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '72903000000.00',
#   'minorityInterest': None,
#   'netIncome': '59531000000.00',
#   'sellingGeneralAdministrative': '16705000000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '101839000000.00',
#   'reconciledDepreciation': '10903000000.00',
#   'ebit': '76143000000.00',
#   'ebitda': '87046000000.00',
#   'depreciationAndAmortization': '10903000000.00',
#   'nonOperatingIncomeNetOther': '2005000000.00',
#   'operatingIncome': '70898000000.00',
#   'otherOperatingExpenses': '194697000000.00',
#   'interestExpense': '3240000000.00',
#   'taxProvision': '13372000000.00',
#   'interestIncome': '5686000000.00',
#   'netInterestIncome': '2446000000.00',
#   'extraordinaryItems': '-1515000000.00',
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '13372000000.00',
#   'totalRevenue': '265595000000.00',
#   'totalOperatingExpenses': '30941000000.00',
#   'costOfRevenue': '163756000000.00',
#   'totalOtherIncomeExpenseNet': '-2005000000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': '59531000000.00',
#   'netIncomeApplicableToCommonShares': '59531000000.00',
#   'preferredStockAndOtherAdjustments': None},
#  '2017-09-30': {'date': '2017-09-30',
#   'filing_date': '2017-11-03',
#   'currency_symbol': 'USD',
#   'researchDevelopment': '11581000000.00',
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '64089000000.00',
#   'minorityInterest': None,
#   'netIncome': '48351000000.00',
#   'sellingGeneralAdministrative': '15261000000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '88186000000.00',
#   'reconciledDepreciation': '10157000000.00',
#   'ebit': '66412000000.00',
#   'ebitda': '76569000000.00',
#   'depreciationAndAmortization': '10157000000.00',
#   'nonOperatingIncomeNetOther': '2745000000.00',
#   'operatingIncome': '61344000000.00',
#   'otherOperatingExpenses': '167890000000.00',
#   'interestExpense': '2323000000.00',
#   'taxProvision': '15738000000.00',
#   'interestIncome': '5201000000.00',
#   'netInterestIncome': '2878000000.00',
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '15738000000.00',
#   'totalRevenue': '229234000000.00',
#   'totalOperatingExpenses': '26842000000.00',
#   'costOfRevenue': '141048000000.00',
#   'totalOtherIncomeExpenseNet': '-2745000000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': '48351000000.00',
#   'netIncomeApplicableToCommonShares': '48351000000.00',
#   'preferredStockAndOtherAdjustments': None},
#  '2016-09-30': {'date': '2016-09-30',
#   'filing_date': '2016-10-26',
#   'currency_symbol': 'USD',
#   'researchDevelopment': '10045000000.00',
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '61372000000.00',
#   'minorityInterest': None,
#   'netIncome': '45687000000.00',
#   'sellingGeneralAdministrative': '14194000000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '84263000000.00',
#   'reconciledDepreciation': None,
#   'ebit': '62828000000.00',
#   'ebitda': '73333000000.00',
#   'depreciationAndAmortization': '10505000000.00',
#   'nonOperatingIncomeNetOther': '1348000000.00',
#   'operatingIncome': '60024000000.00',
#   'otherOperatingExpenses': '155615000000.00',
#   'interestExpense': '1456000000.00',
#   'taxProvision': '15685000000.00',
#   'interestIncome': '3999000000.00',
#   'netInterestIncome': '2543000000.00',
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '15685000000.00',
#   'totalRevenue': '215639000000.00',
#   'totalOperatingExpenses': '24239000000.00',
#   'costOfRevenue': '131376000000.00',
#   'totalOtherIncomeExpenseNet': '-1348000000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': '45687000000.00',
#   'netIncomeApplicableToCommonShares': '45687000000.00',
#   'preferredStockAndOtherAdjustments': None},
#  '2015-09-30': {'date': '2015-09-30',
#   'filing_date': '2015-10-28',
#   'currency_symbol': 'USD',
#   'researchDevelopment': '8067000000.00',
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '72515000000.00',
#   'minorityInterest': None,
#   'netIncome': '53394000000.00',
#   'sellingGeneralAdministrative': '14329000000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '93626000000.00',
#   'reconciledDepreciation': None,
#   'ebit': '73248000000.00',
#   'ebitda': '84505000000.00',
#   'depreciationAndAmortization': '11257000000.00',
#   'nonOperatingIncomeNetOther': '1285000000.00',
#   'operatingIncome': '71230000000.00',
#   'otherOperatingExpenses': '162485000000.00',
#   'interestExpense': '733000000.00',
#   'taxProvision': '19121000000.00',
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '19121000000.00',
#   'totalRevenue': '233715000000.00',
#   'totalOperatingExpenses': '22396000000.00',
#   'costOfRevenue': '140089000000.00',
#   'totalOtherIncomeExpenseNet': '-1285000000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': '53394000000.00',
#   'netIncomeApplicableToCommonShares': '53394000000.00',
#   'preferredStockAndOtherAdjustments': None},
#  '2014-09-30': {'date': '2014-09-30',
#   'filing_date': '2014-10-27',
#   'currency_symbol': 'USD',
#   'researchDevelopment': '6041000000.00',
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '53483000000.00',
#   'minorityInterest': None,
#   'netIncome': '39510000000.00',
#   'sellingGeneralAdministrative': '11993000000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '70537000000.00',
#   'reconciledDepreciation': None,
#   'ebit': '53867000000.00',
#   'ebitda': '61813000000.00',
#   'depreciationAndAmortization': '7946000000.00',
#   'nonOperatingIncomeNetOther': '980000000.00',
#   'operatingIncome': '52503000000.00',
#   'otherOperatingExpenses': '130292000000.00',
#   'interestExpense': '384000000.00',
#   'taxProvision': None,
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '13973000000.00',
#   'totalRevenue': '182795000000.00',
#   'totalOperatingExpenses': '18034000000.00',
#   'costOfRevenue': '112258000000.00',
#   'totalOtherIncomeExpenseNet': '-980000000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': '39510000000.00',
#   'netIncomeApplicableToCommonShares': '39510000000.00',
#   'preferredStockAndOtherAdjustments': None},
#  '2013-09-30': {'date': '2013-09-30',
#   'filing_date': '2013-10-30',
#   'currency_symbol': 'USD',
#   'researchDevelopment': '4475000000.00',
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '50155000000.00',
#   'minorityInterest': None,
#   'netIncome': '37037000000.00',
#   'sellingGeneralAdministrative': '10830000000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '64304000000.00',
#   'reconciledDepreciation': None,
#   'ebit': '50291000000.00',
#   'ebitda': '57048000000.00',
#   'depreciationAndAmortization': '6757000000.00',
#   'nonOperatingIncomeNetOther': '1156000000.00',
#   'operatingIncome': '48999000000.00',
#   'otherOperatingExpenses': '121911000000.00',
#   'interestExpense': '136000000.00',
#   'taxProvision': None,
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '13118000000.00',
#   'totalRevenue': '170910000000.00',
#   'totalOperatingExpenses': '15305000000.00',
#   'costOfRevenue': '106606000000.00',
#   'totalOtherIncomeExpenseNet': '-1156000000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': '37037000000.00',
#   'netIncomeApplicableToCommonShares': '37037000000.00',
#   'preferredStockAndOtherAdjustments': None},
#  '2012-09-30': {'date': '2012-09-30',
#   'filing_date': '2012-10-31',
#   'currency_symbol': 'USD',
#   'researchDevelopment': '3381000000.00',
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '55763000000.00',
#   'minorityInterest': None,
#   'netIncome': '41733000000.00',
#   'sellingGeneralAdministrative': '10040000000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '68662000000.00',
#   'reconciledDepreciation': None,
#   'ebit': '55763000000.00',
#   'ebitda': '59040000000.00',
#   'depreciationAndAmortization': '3277000000.00',
#   'nonOperatingIncomeNetOther': '522000000.00',
#   'operatingIncome': '55241000000.00',
#   'otherOperatingExpenses': '101267000000.00',
#   'interestExpense': '0.00',
#   'taxProvision': None,
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '14030000000.00',
#   'totalRevenue': '156508000000.00',
#   'totalOperatingExpenses': '13421000000.00',
#   'costOfRevenue': '87846000000.00',
#   'totalOtherIncomeExpenseNet': '-522000000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': '41733000000.00',
#   'netIncomeApplicableToCommonShares': '41733000000.00',
#   'preferredStockAndOtherAdjustments': None},
#  '2011-09-30': {'date': '2011-09-30',
#   'filing_date': '2011-10-26',
#   'currency_symbol': 'USD',
#   'researchDevelopment': '2429000000.00',
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '34205000000.00',
#   'minorityInterest': None,
#   'netIncome': '25922000000.00',
#   'sellingGeneralAdministrative': '7599000000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '43818000000.00',
#   'reconciledDepreciation': None,
#   'ebit': '34205000000.00',
#   'ebitda': '36019000000.00',
#   'depreciationAndAmortization': '1814000000.00',
#   'nonOperatingIncomeNetOther': '415000000.00',
#   'operatingIncome': '33790000000.00',
#   'otherOperatingExpenses': '74459000000.00',
#   'interestExpense': '0.00',
#   'taxProvision': None,
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '8283000000.00',
#   'totalRevenue': '108249000000.00',
#   'totalOperatingExpenses': '10028000000.00',
#   'costOfRevenue': '64431000000.00',
#   'totalOtherIncomeExpenseNet': '-415000000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': '25922000000.00',
#   'netIncomeApplicableToCommonShares': '25922000000.00',
#   'preferredStockAndOtherAdjustments': None},
#  '2010-09-30': {'date': '2010-09-30',
#   'filing_date': '2010-10-27',
#   'currency_symbol': 'USD',
#   'researchDevelopment': '1782000000.00',
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '18540000000.00',
#   'minorityInterest': None,
#   'netIncome': '14013000000.00',
#   'sellingGeneralAdministrative': '5517000000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '25684000000.00',
#   'reconciledDepreciation': None,
#   'ebit': '18540000000.00',
#   'ebitda': '19567000000.00',
#   'depreciationAndAmortization': '1027000000.00',
#   'nonOperatingIncomeNetOther': '155000000.00',
#   'operatingIncome': '18385000000.00',
#   'otherOperatingExpenses': '46840000000.00',
#   'interestExpense': '0.00',
#   'taxProvision': None,
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '4527000000.00',
#   'totalRevenue': '65225000000.00',
#   'totalOperatingExpenses': '7299000000.00',
#   'costOfRevenue': '39541000000.00',
#   'totalOtherIncomeExpenseNet': '-155000000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': '14013000000.00',
#   'netIncomeApplicableToCommonShares': '14013000000.00',
#   'preferredStockAndOtherAdjustments': None},
#  '2009-09-30': {'date': '2009-09-30',
#   'filing_date': '2009-10-27',
#   'currency_symbol': 'USD',
#   'researchDevelopment': '1333000000.00',
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '7984000000.00',
#   'minorityInterest': None,
#   'netIncome': '5704000000.00',
#   'sellingGeneralAdministrative': '4149000000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '13140000000.00',
#   'reconciledDepreciation': None,
#   'ebit': '7984000000.00',
#   'ebitda': '8718000000.00',
#   'depreciationAndAmortization': '734000000.00',
#   'nonOperatingIncomeNetOther': '326000000.00',
#   'operatingIncome': '7658000000.00',
#   'otherOperatingExpenses': '28879000000.00',
#   'interestExpense': '0.00',
#   'taxProvision': None,
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '2280000000.00',
#   'totalRevenue': '36537000000.00',
#   'totalOperatingExpenses': '5482000000.00',
#   'costOfRevenue': '23397000000.00',
#   'totalOtherIncomeExpenseNet': '-326000000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': '8235000000.00',
#   'netIncomeApplicableToCommonShares': '8235000000.00',
#   'preferredStockAndOtherAdjustments': None},
#  '2008-09-30': {'date': '2008-09-30',
#   'filing_date': '2008-11-05',
#   'currency_symbol': 'USD',
#   'researchDevelopment': '1109000000.00',
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '6895000000.00',
#   'minorityInterest': None,
#   'netIncome': '4834000000.00',
#   'sellingGeneralAdministrative': '3761000000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '11145000000.00',
#   'reconciledDepreciation': None,
#   'ebit': '6895000000.00',
#   'ebitda': '7368000000.00',
#   'depreciationAndAmortization': '473000000.00',
#   'nonOperatingIncomeNetOther': None,
#   'operatingIncome': '6275000000.00',
#   'otherOperatingExpenses': '26204000000.00',
#   'interestExpense': None,
#   'taxProvision': None,
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '2061000000.00',
#   'totalRevenue': '32479000000.00',
#   'totalOperatingExpenses': '4870000000.00',
#   'costOfRevenue': '21334000000.00',
#   'totalOtherIncomeExpenseNet': '-620000000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': None,
#   'netIncomeApplicableToCommonShares': '4834000000.00',
#   'preferredStockAndOtherAdjustments': None},
#  '2007-09-30': {'date': '2007-09-30',
#   'filing_date': '2007-11-15',
#   'currency_symbol': 'USD',
#   'researchDevelopment': '782000000.00',
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '5008000000.00',
#   'minorityInterest': None,
#   'netIncome': '3496000000.00',
#   'sellingGeneralAdministrative': '2963000000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '8154000000.00',
#   'reconciledDepreciation': None,
#   'ebit': '5008000000.00',
#   'ebitda': '5325000000.00',
#   'depreciationAndAmortization': '317000000.00',
#   'nonOperatingIncomeNetOther': None,
#   'operatingIncome': '4409000000.00',
#   'otherOperatingExpenses': '19597000000.00',
#   'interestExpense': None,
#   'taxProvision': None,
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '1512000000.00',
#   'totalRevenue': '24006000000.00',
#   'totalOperatingExpenses': '3745000000.00',
#   'costOfRevenue': '15852000000.00',
#   'totalOtherIncomeExpenseNet': '-599000000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': None,
#   'netIncomeApplicableToCommonShares': '3496000000.00',
#   'preferredStockAndOtherAdjustments': None},
#  '2006-09-30': {'date': '2006-09-30',
#   'filing_date': '2006-12-29',
#   'currency_symbol': 'USD',
#   'researchDevelopment': '712000000.00',
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '2818000000.00',
#   'minorityInterest': None,
#   'netIncome': '1989000000.00',
#   'sellingGeneralAdministrative': '2433000000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '5598000000.00',
#   'reconciledDepreciation': None,
#   'ebit': '2818000000.00',
#   'ebitda': '3043000000.00',
#   'depreciationAndAmortization': '225000000.00',
#   'nonOperatingIncomeNetOther': None,
#   'operatingIncome': '2453000000.00',
#   'otherOperatingExpenses': '16862000000.00',
#   'interestExpense': None,
#   'taxProvision': None,
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '829000000.00',
#   'totalRevenue': '19315000000.00',
#   'totalOperatingExpenses': '3145000000.00',
#   'costOfRevenue': '13717000000.00',
#   'totalOtherIncomeExpenseNet': '-365000000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': None,
#   'netIncomeApplicableToCommonShares': '1989000000.00',
#   'preferredStockAndOtherAdjustments': None},
#  '2005-09-30': {'date': '2005-09-30',
#   'filing_date': '2005-12-01',
#   'currency_symbol': 'USD',
#   'researchDevelopment': '534000000.00',
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '1815000000.00',
#   'minorityInterest': None,
#   'netIncome': '1335000000.00',
#   'sellingGeneralAdministrative': '1859000000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '4043000000.00',
#   'reconciledDepreciation': None,
#   'ebit': '1815000000.00',
#   'ebitda': '1994000000.00',
#   'depreciationAndAmortization': '179000000.00',
#   'nonOperatingIncomeNetOther': None,
#   'operatingIncome': '1650000000.00',
#   'otherOperatingExpenses': '12281000000.00',
#   'interestExpense': None,
#   'taxProvision': None,
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '480000000.00',
#   'totalRevenue': '13931000000.00',
#   'totalOperatingExpenses': '2393000000.00',
#   'costOfRevenue': '9888000000.00',
#   'totalOtherIncomeExpenseNet': '-165000000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': None,
#   'netIncomeApplicableToCommonShares': '1335000000.00',
#   'preferredStockAndOtherAdjustments': None},
#  '2004-09-30': {'date': '2004-09-30',
#   'filing_date': '2004-12-03',
#   'currency_symbol': 'USD',
#   'researchDevelopment': '489000000.00',
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '383000000.00',
#   'minorityInterest': None,
#   'netIncome': '276000000.00',
#   'sellingGeneralAdministrative': '1421000000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '2259000000.00',
#   'reconciledDepreciation': None,
#   'ebit': '386000000.00',
#   'ebitda': '536000000.00',
#   'depreciationAndAmortization': '150000000.00',
#   'nonOperatingIncomeNetOther': None,
#   'operatingIncome': '349000000.00',
#   'otherOperatingExpenses': '7930000000.00',
#   'interestExpense': '3000000.00',
#   'taxProvision': None,
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '107000000.00',
#   'totalRevenue': '8279000000.00',
#   'totalOperatingExpenses': '1910000000.00',
#   'costOfRevenue': '6020000000.00',
#   'totalOtherIncomeExpenseNet': '-34000000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': None,
#   'netIncomeApplicableToCommonShares': '276000000.00',
#   'preferredStockAndOtherAdjustments': None},
#  '2003-09-30': {'date': '2003-09-30',
#   'filing_date': '2003-12-19',
#   'currency_symbol': 'USD',
#   'researchDevelopment': '471000000.00',
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '92000000.00',
#   'minorityInterest': None,
#   'netIncome': '69000000.00',
#   'sellingGeneralAdministrative': '1212000000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '1708000000.00',
#   'reconciledDepreciation': None,
#   'ebit': '101000000.00',
#   'ebitda': '214000000.00',
#   'depreciationAndAmortization': '113000000.00',
#   'nonOperatingIncomeNetOther': None,
#   'operatingIncome': '25000000.00',
#   'otherOperatingExpenses': '6182000000.00',
#   'interestExpense': '8000000.00',
#   'taxProvision': None,
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': '1000000.00',
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '24000000.00',
#   'totalRevenue': '6207000000.00',
#   'totalOperatingExpenses': '1683000000.00',
#   'costOfRevenue': '4499000000.00',
#   'totalOtherIncomeExpenseNet': '-67000000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': None,
#   'netIncomeApplicableToCommonShares': '68000000.00',
#   'preferredStockAndOtherAdjustments': None},
#  '2002-09-30': {'date': '2002-09-30',
#   'filing_date': '2002-12-19',
#   'currency_symbol': 'USD',
#   'researchDevelopment': '447000000.00',
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '87000000.00',
#   'minorityInterest': None,
#   'netIncome': '65000000.00',
#   'sellingGeneralAdministrative': '1111000000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '1603000000.00',
#   'reconciledDepreciation': None,
#   'ebit': '98000000.00',
#   'ebitda': '212000000.00',
#   'depreciationAndAmortization': '114000000.00',
#   'nonOperatingIncomeNetOther': None,
#   'operatingIncome': '45000000.00',
#   'otherOperatingExpenses': '5697000000.00',
#   'interestExpense': '11000000.00',
#   'taxProvision': None,
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '22000000.00',
#   'totalRevenue': '5742000000.00',
#   'totalOperatingExpenses': '1558000000.00',
#   'costOfRevenue': '4139000000.00',
#   'totalOtherIncomeExpenseNet': '-42000000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': None,
#   'netIncomeApplicableToCommonShares': '65000000.00',
#   'preferredStockAndOtherAdjustments': None},
#  '2001-09-30': {'date': '2001-09-30',
#   'filing_date': '2001-12-21',
#   'currency_symbol': 'USD',
#   'researchDevelopment': '441000000.00',
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '-52000000.00',
#   'minorityInterest': None,
#   'netIncome': '-25000000.00',
#   'sellingGeneralAdministrative': '1138000000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '1235000000.00',
#   'reconciledDepreciation': None,
#   'ebit': '-24000000.00',
#   'ebitda': '76000000.00',
#   'depreciationAndAmortization': '100000000.00',
#   'nonOperatingIncomeNetOther': None,
#   'operatingIncome': '-344000000.00',
#   'otherOperatingExpenses': '5707000000.00',
#   'interestExpense': '16000000.00',
#   'taxProvision': None,
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': '12000000.00',
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '-15000000.00',
#   'totalRevenue': '5363000000.00',
#   'totalOperatingExpenses': '1579000000.00',
#   'costOfRevenue': '4128000000.00',
#   'totalOtherIncomeExpenseNet': '-292000000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': None,
#   'netIncomeApplicableToCommonShares': None,
#   'preferredStockAndOtherAdjustments': None},
#  '2000-09-30': {'date': '2000-09-30',
#   'filing_date': '2000-12-14',
#   'currency_symbol': 'USD',
#   'researchDevelopment': '380000000.00',
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '1092000000.00',
#   'minorityInterest': None,
#   'netIncome': '786000000.00',
#   'sellingGeneralAdministrative': '1166000000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '2166000000.00',
#   'reconciledDepreciation': None,
#   'ebit': '1113000000.00',
#   'ebitda': '1197000000.00',
#   'depreciationAndAmortization': '84000000.00',
#   'nonOperatingIncomeNetOther': None,
#   'operatingIncome': '620000000.00',
#   'otherOperatingExpenses': '7363000000.00',
#   'interestExpense': '21000000.00',
#   'taxProvision': None,
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '306000000.00',
#   'totalRevenue': '7983000000.00',
#   'totalOperatingExpenses': '1546000000.00',
#   'costOfRevenue': '5817000000.00',
#   'totalOtherIncomeExpenseNet': '-472000000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': None,
#   'netIncomeApplicableToCommonShares': '786000000.00',
#   'preferredStockAndOtherAdjustments': None},
#  '1999-09-30': {'date': '1999-09-30',
#   'filing_date': '1999-12-22',
#   'currency_symbol': None,
#   'researchDevelopment': '314000000.00',
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '676000000.00',
#   'minorityInterest': None,
#   'netIncome': '601000000.00',
#   'sellingGeneralAdministrative': '996000000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '1696000000.00',
#   'reconciledDepreciation': None,
#   'ebit': '723000000.00',
#   'ebitda': '808000000.00',
#   'depreciationAndAmortization': '85000000.00',
#   'nonOperatingIncomeNetOther': None,
#   'operatingIncome': '386000000.00',
#   'otherOperatingExpenses': '5748000000.00',
#   'interestExpense': '47000000.00',
#   'taxProvision': None,
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '75000000.00',
#   'totalRevenue': '6134000000.00',
#   'totalOperatingExpenses': '1310000000.00',
#   'costOfRevenue': '4438000000.00',
#   'totalOtherIncomeExpenseNet': '-290000000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': None,
#   'netIncomeApplicableToCommonShares': None,
#   'preferredStockAndOtherAdjustments': None},
#  '1998-09-30': {'date': '1998-09-30',
#   'filing_date': '1998-09-25',
#   'currency_symbol': None,
#   'researchDevelopment': '310000000.00',
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '329000000.00',
#   'minorityInterest': None,
#   'netIncome': '309000000.00',
#   'sellingGeneralAdministrative': '908000000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '1479000000.00',
#   'reconciledDepreciation': None,
#   'ebit': '391000000.00',
#   'ebitda': '502000000.00',
#   'depreciationAndAmortization': '111000000.00',
#   'nonOperatingIncomeNetOther': None,
#   'operatingIncome': '261000000.00',
#   'otherOperatingExpenses': '5680000000.00',
#   'interestExpense': '62000000.00',
#   'taxProvision': None,
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '20000000.00',
#   'totalRevenue': '5941000000.00',
#   'totalOperatingExpenses': '1218000000.00',
#   'costOfRevenue': '4462000000.00',
#   'totalOtherIncomeExpenseNet': '-68000000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': None,
#   'netIncomeApplicableToCommonShares': None,
#   'preferredStockAndOtherAdjustments': None},
#  '1997-09-30': {'date': '1997-09-30',
#   'filing_date': '1997-12-05',
#   'currency_symbol': None,
#   'researchDevelopment': '860000000.00',
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '-1045000000.00',
#   'minorityInterest': None,
#   'netIncome': '-1045000000.00',
#   'sellingGeneralAdministrative': '1286000000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '1368000000.00',
#   'reconciledDepreciation': None,
#   'ebit': '-778000000.00',
#   'ebitda': '-660000000.00',
#   'depreciationAndAmortization': '118000000.00',
#   'nonOperatingIncomeNetOther': None,
#   'operatingIncome': '-778000000.00',
#   'otherOperatingExpenses': '7859000000.00',
#   'interestExpense': '71000000.00',
#   'taxProvision': None,
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': None,
#   'totalRevenue': '7081000000.00',
#   'totalOperatingExpenses': '2146000000.00',
#   'costOfRevenue': '5713000000.00',
#   'totalOtherIncomeExpenseNet': '267000000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': None,
#   'netIncomeApplicableToCommonShares': None,
#   'preferredStockAndOtherAdjustments': None},
#  '1996-09-30': {'date': '1996-09-30',
#   'filing_date': '1996-12-19',
#   'currency_symbol': None,
#   'researchDevelopment': '604000000.00',
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '-1295000000.00',
#   'minorityInterest': None,
#   'netIncome': '-816000000.00',
#   'sellingGeneralAdministrative': '1568000000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '968000000.00',
#   'reconciledDepreciation': None,
#   'ebit': '-1235000000.00',
#   'ebitda': '-1079000000.00',
#   'depreciationAndAmortization': '156000000.00',
#   'nonOperatingIncomeNetOther': None,
#   'operatingIncome': '-1204000000.00',
#   'otherOperatingExpenses': '11037000000.00',
#   'interestExpense': '60000000.00',
#   'taxProvision': None,
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '-479000000.00',
#   'totalRevenue': '9833000000.00',
#   'totalOperatingExpenses': '2172000000.00',
#   'costOfRevenue': '8865000000.00',
#   'totalOtherIncomeExpenseNet': '91000000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': None,
#   'netIncomeApplicableToCommonShares': None,
#   'preferredStockAndOtherAdjustments': None},
#  '1995-09-30': {'date': '1995-09-30',
#   'filing_date': '1995-12-19',
#   'currency_symbol': None,
#   'researchDevelopment': '614000000.00',
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '674000000.00',
#   'minorityInterest': None,
#   'netIncome': '424000000.00',
#   'sellingGeneralAdministrative': '1583000000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '2858000000.00',
#   'reconciledDepreciation': None,
#   'ebit': '722000000.00',
#   'ebitda': '849000000.00',
#   'depreciationAndAmortization': '127000000.00',
#   'nonOperatingIncomeNetOther': None,
#   'operatingIncome': '661000000.00',
#   'otherOperatingExpenses': '10401000000.00',
#   'interestExpense': '48000000.00',
#   'taxProvision': None,
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '250000000.00',
#   'totalRevenue': '11062000000.00',
#   'totalOperatingExpenses': '2197000000.00',
#   'costOfRevenue': '8204000000.00',
#   'totalOtherIncomeExpenseNet': '-13000000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': None,
#   'netIncomeApplicableToCommonShares': None,
#   'preferredStockAndOtherAdjustments': None},
#  '1994-09-30': {'date': '1994-09-30',
#   'filing_date': '1994-12-13',
#   'currency_symbol': None,
#   'researchDevelopment': '564303000.00',
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '500286000.00',
#   'minorityInterest': None,
#   'netIncome': '310178000.00',
#   'sellingGeneralAdministrative': '1384111000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '2343833000.00',
#   'reconciledDepreciation': None,
#   'ebit': '539939000.00',
#   'ebitda': '707897000.00',
#   'depreciationAndAmortization': '167958000.00',
#   'nonOperatingIncomeNetOther': None,
#   'operatingIncome': '395419000.00',
#   'otherOperatingExpenses': '8793329000.00',
#   'interestExpense': '39653000.00',
#   'taxProvision': None,
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '190108000.00',
#   'totalRevenue': '9188748000.00',
#   'totalOperatingExpenses': '1948414000.00',
#   'costOfRevenue': '6844915000.00',
#   'totalOtherIncomeExpenseNet': '-104867000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': None,
#   'netIncomeApplicableToCommonShares': None,
#   'preferredStockAndOtherAdjustments': None},
#  '1993-09-30': {'date': '1993-09-30',
#   'filing_date': '1993-09-30',
#   'currency_symbol': None,
#   'researchDevelopment': None,
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '139700000.00',
#   'minorityInterest': None,
#   'netIncome': '86600000.00',
#   'sellingGeneralAdministrative': '2617800000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '2894300000.00',
#   'reconciledDepreciation': None,
#   'ebit': '139700000.00',
#   'ebitda': '305800000.00',
#   'depreciationAndAmortization': '166100000.00',
#   'nonOperatingIncomeNetOther': None,
#   'operatingIncome': '110400000.00',
#   'otherOperatingExpenses': '7866600000.00',
#   'interestExpense': None,
#   'taxProvision': None,
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '53100000.00',
#   'totalRevenue': '7977000000.00',
#   'totalOperatingExpenses': '2783900000.00',
#   'costOfRevenue': '5082700000.00',
#   'totalOtherIncomeExpenseNet': '-29300000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': None,
#   'netIncomeApplicableToCommonShares': None,
#   'preferredStockAndOtherAdjustments': None},
#  '1992-09-30': {'date': '1992-09-30',
#   'filing_date': '1992-09-30',
#   'currency_symbol': None,
#   'researchDevelopment': None,
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '855500000.00',
#   'minorityInterest': None,
#   'netIncome': '530400000.00',
#   'sellingGeneralAdministrative': '2289400000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '3312300000.00',
#   'reconciledDepreciation': None,
#   'ebit': '855500000.00',
#   'ebitda': '1072700000.00',
#   'depreciationAndAmortization': '217200000.00',
#   'nonOperatingIncomeNetOther': None,
#   'operatingIncome': '805700000.00',
#   'otherOperatingExpenses': '6280800000.00',
#   'interestExpense': None,
#   'taxProvision': None,
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '325100000.00',
#   'totalRevenue': '7086500000.00',
#   'totalOperatingExpenses': '2506600000.00',
#   'costOfRevenue': '3774200000.00',
#   'totalOtherIncomeExpenseNet': '-49800000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': None,
#   'netIncomeApplicableToCommonShares': None,
#   'preferredStockAndOtherAdjustments': None},
#  '1991-09-30': {'date': '1991-09-30',
#   'filing_date': '1991-09-30',
#   'currency_symbol': None,
#   'researchDevelopment': None,
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '499700000.00',
#   'minorityInterest': None,
#   'netIncome': '309800000.00',
#   'sellingGeneralAdministrative': '2547400000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '3199100000.00',
#   'reconciledDepreciation': None,
#   'ebit': '499700000.00',
#   'ebitda': '704100000.00',
#   'depreciationAndAmortization': '204400000.00',
#   'nonOperatingIncomeNetOther': None,
#   'operatingIncome': '447300000.00',
#   'otherOperatingExpenses': '5861500000.00',
#   'interestExpense': None,
#   'taxProvision': None,
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '189900000.00',
#   'totalRevenue': '6308800000.00',
#   'totalOperatingExpenses': '2751800000.00',
#   'costOfRevenue': '3109700000.00',
#   'totalOtherIncomeExpenseNet': '-52400000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': None,
#   'netIncomeApplicableToCommonShares': None,
#   'preferredStockAndOtherAdjustments': None},
#  '1990-09-30': {'date': '1990-09-30',
#   'filing_date': '1990-09-30',
#   'currency_symbol': None,
#   'researchDevelopment': None,
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '778500000.00',
#   'minorityInterest': None,
#   'netIncome': '474900000.00',
#   'sellingGeneralAdministrative': '2240200000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '3154900000.00',
#   'reconciledDepreciation': None,
#   'ebit': '778500000.00',
#   'ebitda': '981200000.00',
#   'depreciationAndAmortization': '202700000.00',
#   'nonOperatingIncomeNetOther': None,
#   'operatingIncome': '712000000.00',
#   'otherOperatingExpenses': '4846400000.00',
#   'interestExpense': None,
#   'taxProvision': None,
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '303600000.00',
#   'totalRevenue': '5558400000.00',
#   'totalOperatingExpenses': '2442900000.00',
#   'costOfRevenue': '2403500000.00',
#   'totalOtherIncomeExpenseNet': '-66500000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': None,
#   'netIncomeApplicableToCommonShares': None,
#   'preferredStockAndOtherAdjustments': None},
#  '1989-09-30': {'date': '1989-09-30',
#   'filing_date': '1989-09-30',
#   'currency_symbol': None,
#   'researchDevelopment': None,
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '744300000.00',
#   'minorityInterest': None,
#   'netIncome': '454000000.00',
#   'sellingGeneralAdministrative': '1954900000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '2714000000.00',
#   'reconciledDepreciation': None,
#   'ebit': '744300000.00',
#   'ebitda': '869100000.00',
#   'depreciationAndAmortization': '124800000.00',
#   'nonOperatingIncomeNetOther': None,
#   'operatingIncome': '634300000.00',
#   'otherOperatingExpenses': '4649700000.00',
#   'interestExpense': None,
#   'taxProvision': None,
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '290300000.00',
#   'totalRevenue': '5284000000.00',
#   'totalOperatingExpenses': '2079700000.00',
#   'costOfRevenue': '2570000000.00',
#   'totalOtherIncomeExpenseNet': '-110000000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': None,
#   'netIncomeApplicableToCommonShares': None,
#   'preferredStockAndOtherAdjustments': None},
#  '1988-09-30': {'date': '1988-09-30',
#   'filing_date': '1988-09-30',
#   'currency_symbol': None,
#   'researchDevelopment': None,
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '656200000.00',
#   'minorityInterest': None,
#   'netIncome': '400300000.00',
#   'sellingGeneralAdministrative': '1460200000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '2158200000.00',
#   'reconciledDepreciation': None,
#   'ebit': '656200000.00',
#   'ebitda': '733900000.00',
#   'depreciationAndAmortization': '77700000.00',
#   'nonOperatingIncomeNetOther': None,
#   'operatingIncome': '620300000.00',
#   'otherOperatingExpenses': '3451100000.00',
#   'interestExpense': None,
#   'taxProvision': None,
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '255900000.00',
#   'totalRevenue': '4071400000.00',
#   'totalOperatingExpenses': '1537900000.00',
#   'costOfRevenue': '1913200000.00',
#   'totalOtherIncomeExpenseNet': '-35900000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': None,
#   'netIncomeApplicableToCommonShares': None,
#   'preferredStockAndOtherAdjustments': None},
#  '1987-09-30': {'date': '1987-09-30',
#   'filing_date': '1987-09-30',
#   'currency_symbol': None,
#   'researchDevelopment': None,
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '410400000.00',
#   'minorityInterest': None,
#   'netIncome': '217500000.00',
#   'sellingGeneralAdministrative': '993400000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '1435400000.00',
#   'reconciledDepreciation': None,
#   'ebit': '410400000.00',
#   'ebitda': '480900000.00',
#   'depreciationAndAmortization': '70500000.00',
#   'nonOperatingIncomeNetOther': None,
#   'operatingIncome': '371500000.00',
#   'otherOperatingExpenses': '2289600000.00',
#   'interestExpense': None,
#   'taxProvision': None,
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '192900000.00',
#   'totalRevenue': '2661100000.00',
#   'totalOperatingExpenses': '1063900000.00',
#   'costOfRevenue': '1225700000.00',
#   'totalOtherIncomeExpenseNet': '-38900000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': None,
#   'netIncomeApplicableToCommonShares': None,
#   'preferredStockAndOtherAdjustments': None},
#  '1986-09-30': {'date': '1986-09-30',
#   'filing_date': '1986-09-30',
#   'currency_symbol': None,
#   'researchDevelopment': None,
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '309800000.00',
#   'minorityInterest': None,
#   'netIncome': '154000000.00',
#   'sellingGeneralAdministrative': '737300000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '1061900000.00',
#   'reconciledDepreciation': None,
#   'ebit': '309800000.00',
#   'ebitda': '360900000.00',
#   'depreciationAndAmortization': '51100000.00',
#   'nonOperatingIncomeNetOther': None,
#   'operatingIncome': '273500000.00',
#   'otherOperatingExpenses': '1628400000.00',
#   'interestExpense': None,
#   'taxProvision': None,
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '155800000.00',
#   'totalRevenue': '1901900000.00',
#   'totalOperatingExpenses': '788400000.00',
#   'costOfRevenue': '840000000.00',
#   'totalOtherIncomeExpenseNet': '-36300000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': None,
#   'netIncomeApplicableToCommonShares': None,
#   'preferredStockAndOtherAdjustments': None},
#  '1985-09-30': {'date': '1985-09-30',
#   'filing_date': '1985-09-30',
#   'currency_symbol': None,
#   'researchDevelopment': None,
#   'effectOfAccountingCharges': None,
#   'incomeBeforeTax': '120000000.00',
#   'minorityInterest': None,
#   'netIncome': '61200000.00',
#   'sellingGeneralAdministrative': '653200000.00',
#   'sellingAndMarketingExpenses': None,
#   'grossProfit': '842300000.00',
#   'reconciledDepreciation': None,
#   'ebit': '120000000.00',
#   'ebitda': '161800000.00',
#   'depreciationAndAmortization': '41800000.00',
#   'nonOperatingIncomeNetOther': None,
#   'operatingIncome': '147300000.00',
#   'otherOperatingExpenses': '1771000000.00',
#   'interestExpense': None,
#   'taxProvision': None,
#   'interestIncome': None,
#   'netInterestIncome': None,
#   'extraordinaryItems': None,
#   'nonRecurring': None,
#   'otherItems': None,
#   'incomeTaxExpense': '58800000.00',
#   'totalRevenue': '1918300000.00',
#   'totalOperatingExpenses': '695000000.00',
#   'costOfRevenue': '1076000000.00',
#   'totalOtherIncomeExpenseNet': '27300000.00',
#   'discontinuedOperations': None,
#   'netIncomeFromContinuingOps': None,
#   'netIncomeApplicableToCommonShares': None,
#   'preferredStockAndOtherAdjustments': None}}

# %%
payload['Financials']['Balance_Sheet']['yearly']['2020-09-30']['commonStockSharesOutstanding']
# there is a field for # of common shares outstanding in the balance sheet payload, which is helpful for calculating
# per share metrics
# Out:
# '17528214000.00'

# %% [markdown]
# #### Summary of the income statement
#
# - **data**: it has most needed income metrics such as total net income, operating income, ebit, ebitda, etc.
# - **per share metrics**: although not directly available in the income payload, there is there is a field for # of common shares outstanding in the balance sheet payload, which can be used for calculating per share metrics
# - **consistency of keys across years**: the names of keys in each years income payload, like "ebit", "operatingIncome", etc., all seem to be consistent across different years
